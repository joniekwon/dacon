# %%
import sys
sys.version

import re
from konlpy.tag import Okt          
from konlpy.tag import Komoran
from collections import Counter
import pandas as pd 

import matplotlib
import matplotlib.pyplot as plt
from matplotlib import font_manager, rc
from wordcloud import WordCloud

from hanspell import spell_checker

# %% [markdown]
# ### 형태소 분석 및 품사 태깅 라이브러리
# * https://konlpy.org/ko/v0.4.3/morph/#

# %% [markdown]
# ## 한글 폰트 설정

# %%
font_path ="C:/Windows/fonts/malgun.ttf"
font_name = font_manager.FontProperties(fname=font_path).get_name()
matplotlib.rc('font',family=font_name)

# %%
train = pd.read_csv('_data/train.csv', index_col=0)
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 1 to 5000
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   document  5000 non-null   object
#  1   label     5000 non-null   int64
# dtypes: int64(1), object(1)
# memory usage: 117.2+ KB

# %%
test = pd.read_csv('_data/test.csv', index_col=0)
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5000 entries, 1 to 5000
# Data columns (total 1 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   document  5000 non-null   object
# dtypes: object(1)
# memory usage: 78.1+ KB

# %% [markdown]
# # 형태소 및 단어 분리
# * 영어만으로 작성된 리뷰도 있기 때문에 문자열을 제외한 나머지를 공백으로 치환 (re.sub(r'[^\w]+', ' ', x)

# %%
okt = Okt()
def preprocessing(df):
    df['document'] = df.document.apply(lambda x : re.sub(r'[^0-9a-zA-Zㅏ-ㅣ가-힣]+', ' ', x).strip())
    df['spell_ck'] = df.document.apply(lambda x : spell_checker.check(x).checked)
    df['tokenized_stem'] = df.document.apply(lambda x : ' '.join(okt.morphs(x, stem=True)))
    df['tokenized_stem2'] = df.spell_ck.apply(lambda x : ' '.join(okt.morphs(x, stem=True)))

    return df

# %%
train = preprocessing(train)
train.head()
# Out:
#                                  document  label  \
# id
# 1               영상이나 음악이 이쁘다 해도 미화시킨 불륜일뿐      0
# 2               히치콕이 이 영화를 봤다면 분명 박수를 쳤을듯      1
# 3        괜찮은 음악영화가 또 나왔군요 따뜻한 겨울이 될 것 같아요      1
# 4             아무래도 20년도지난작품이라 지금보기는너무유치하다      0
# 5   지금까지의 영화들이 그랬듯 이 영화역시 일본에 대한 미화는 여전하다      0
#
#                                   spell_ck  \
# id
# 1               영상이나 음악이 이쁘다 해도 미화시킨 불륜일 뿐
# 2               히치콕이 이 영화를 봤다면 분명 손뼉을 쳤을 듯
# 3         괜찮은 음악영화가 또 나왔군요 따뜻한 겨울이 될 것 같아요
# 4         아무래도 20년도 지난 작품이라 지금 보기는 너무 유치하다
# 5   지금까지의 영화들이 그랬듯 이 영화 역시 일본에 대한 미화는 여전하다
#
#                                  tokenized_stem  \
# id
# 1               영상 이나 음악 이 이쁘다 해도 미화 시키다 불륜 일 뿐
# 2                    히치콕 이 이 영화 를 보다 분명 박수 를 치다
# 3           괜찮다 음악 영화 가 또 나오다 따뜻하다 겨울 이 되다 것 같다
# 4              아무래도 20년 도지난작품이라 지금 보기 는 너무 유치하다
# 5   지금 까지의 영화 들 이 그렇다 이 영화 역시 일본 에 대한 미화 는 여전하다
#
#                                 tokenized_stem2
# id
# 1               영상 이나 음악 이 이쁘다 해도 미화 시키다 불륜 일 뿐
# 2                  히치콕 이 이 영화 를 보다 분명 손뼉 을 치다 듯
# 3           괜찮다 음악 영화 가 또 나오다 따뜻하다 겨울 이 되다 것 같다
# 4           아무래도 20년 도 지난 작품 이라 지금 보기 는 너무 유치하다
# 5   지금 까지의 영화 들 이 그렇다 이 영화 역시 일본 에 대한 미화 는 여전하다

# %%
train.tail()
# Out:
#                                     document  label  \
# id
# 4996                좋은 배우들로 3류영화를 찍은 안타까운 영화      0
# 4997  진짜 드럽게 재미없다 에드워드 호퍼 그림에 배경 빼고는 볼게 아닌영화      0
# 4998                   가장 실망스러운 영화 지금까지 본영화중      0
# 4999           이런 평점 테러 네이버에서 좀 막아야 하는 것 아닌가      1
# 5000       여주인공이 전작에서는 귀여웠는데 여기선 완전 망했네 실망이다      0
#
#                                       spell_ck  \
# id
# 4996                 좋은 배우들로 3류 영화를 찍은 안타까운 영화
# 4997  진짜 더럽게 재미없다 에드워드 호퍼 그림에 배경 빼고는 볼 게 아닌 영화
# 4998                   가장 실망스러운 영화 지금까지 본 영화 중
# 4999             이런 평점 테러 네이버에서 좀 막아야 하는 것 아닌가
# 5000         여주인공이 전작에서는 귀여웠는데 여기선 정말 망했네 실망이다
#
#                                  tokenized_stem  \
# id
# 4996              좋다 배우 들 로 3 류 영화 를 찍다 안타깝다 영화
# 4997  진짜 드럽다 재미없다 에드워드 호퍼 그림 에 배경 빼다 볼 게 아니다 영화
# 4998                  가장 실망 스러운 영화 지금 까지 본 영화 중
# 4999             이렇다 평점 테러 네이버 에서 좀 막다 하다 것 아니다
# 5000       여 주인공 이 전작 에서는 귀엽다 여 기선 완전 망하다 실망 이다
#
#                                 tokenized_stem2
# id
# 4996              좋다 배우 들 로 3 류 영화 를 찍다 안타깝다 영화
# 4997  진짜 더럽다 재미없다 에드워드 호퍼 그림 에 배경 빼다 볼 게 아니다 영화
# 4998                 가장 실망 스러운 영화 지금 까지 보다 영화 중
# 4999             이렇다 평점 테러 네이버 에서 좀 막다 하다 것 아니다
# 5000       여 주인공 이 전작 에서는 귀엽다 여 기선 정말 망하다 실망 이다

# %%
X_train = train['tokenized_stem'].values
y_train = train['label'].values

# %%
test = preprocessing(test)
X_test = test['tokenized_stem'].values

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(ngram_range=(1,2),
                       min_df=3,
                       max_df=0.9,
                       tokenizer=okt.morphs,
                       token_pattern=None)
tfidf.fit(X_train)
X_train_okt = tfidf.transform(X_train)
X_test_okt = tfidf.transform(X_test)

# %%
SEED = 32

# %%
from sklearn.model_selection import RandomizedSearchCV
from sklearn.linear_model import SGDClassifier
from sklearn.utils.fixes import loguniform

sgd = SGDClassifier(loss='log', random_state=SEED)
param_dist = {'alpha': loguniform(0.0001, 100.0)}
rsv_okt = RandomizedSearchCV(estimator=sgd, param_distributions=param_dist,
                            n_iter=50, random_state=SEED, verbose=1)
rsv_okt.fit(X_train_okt, y_train)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# RandomizedSearchCV(estimator=SGDClassifier(loss='log', random_state=32),
#                    n_iter=50,
#                    param_distributions={'alpha': <scipy.stats._distn_infrastructure.rv_frozen object at 0x000001819D8E9088>},
#                    random_state=32, verbose=1)

# %%
print(rsv_okt.best_score_)
print(rsv_okt.best_params_)
# Out:
# 0.8664
# {'alpha': 0.00014355463635694167}

# %%
submission = pd.read_csv('./_data/sample_submission.csv')
submission
# Out:
#         id  label
# 0        1      0
# 1        2      0
# 2        3      0
# 3        4      0
# 4        5      0
# ...    ...    ...
# 4995  4996      0
# 4996  4997      0
# 4997  4998      0
# 4998  4999      0
# 4999  5000      0
#
# [5000 rows x 2 columns]

# %% [markdown]
# # 처리가 필요한 것
# 1. 맞춤법, 띄어쓰기가 제대로 안되어 있는 경우 --> py-hanspell를 이용하여 맞춤법 교정 후 예측
# 2. 자음, 모음만 있는 리뷰 (ex.ㅠㅠ ㅋㅋㅋ) --> 테스트에만 있는 케이스
# 3. 영어로만 이루어진 리뷰
# 4. 숫자 (ex.3류) --> 포함하기로함

# %%
inz = [0,0]
inb = [0,0]

for i, s in enumerate(train.document):
    index = train.loc[i+1,'label']
    if ('ㅋ' in s):
        print('[긍정]' if train.loc[i+1, 'label']==1 else '[부정]', i+1, s)
        inz[index]+=1
    elif 'ㅠ' in s:
        print('[긍정]' if train.loc[i+1, 'label']==1 else '[부정]', i+1, s)
        inb[index]+=1
print(f'"ㅋ"이 포함된 부정리뷰 수: {inz[0]}')
print(f'"ㅋ"이 포함된 긍정리뷰 수: {inz[1]}')
print(f'"ㅠ"가 포함된 부정리뷰 수: {inb[0]}')
print(f'"ㅠ"가 포함된 긍정리뷰 수: {inb[1]}')
# Out:
# [긍정] 38 ㅋㅋㅋ역시 피터잭슨 ㅋㅋㅋ완전재밌어 ㅋㅋ
# [긍정] 39 영화평점 작성하신분들 왜케 웃김ㅋㅋㅋ보다가 빵터졌어요ㅋㅋ
# [부정] 46 촌스럽고 지루해여 근데 유동근아내가 선생님팰땐 웃겨ㅛ음ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# [부정] 49 아나 댓글이 더웃겨 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# [긍정] 51 재밌게 잘 봤어요ㅋㅋㅋ 남자너무멋져
# [부정] 83 ㅠㅠ 보면 돈이 아까워서 안됩니다
# [부정] 84 좋은 영화인데 재미가 너무 없다 ㅠㅠ
# [부정] 94 이유없음과정없음설득력없음BGM도없ㅋ음ㅋ감독맘대로 만든것같은 불친절한영화
# [긍정] 110 너무재밌음 ㅋㅋㅋ우리집에 비디오로있는데
# [긍정] 117 개 굿 입니다 보세요 ㅋㅋㅋㅋ
# [긍정] 146 시원하게 웃을 수 있게 해주는 드라마 ㅋ
# [긍정] 163 스티치앓이 중 ㅜㅜ 너무 귀여워서 미치겠다ㅋㅋ 그리고 영화가 완전 감동ㅠㅠ
# [긍정] 164 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ좋네요 뭔가통쾌하고 유머러스하네요
# [부정] 166 이렇게 원작을 망치기도 힘들겠다ㅋ
# [부정] 212 처음에는 나름 좋았는데 아쉽다 허나 배우들이 많이 나오네 ㅋ
# [부정] 223 이게 뭔 액션이냐 개차반이네 ㅋㅋㅋㅋㅋㅋ
# [긍정] 224 나능좋은데 ㅋ 번봐도 초반전쟁씬 전반내용을 이해못하겠엌 영화는 좋음
# [긍정] 239 주군의태양 때문에 보게 됐는데 완전 감동ㅠ ㅠ잊지못할 애니메이션ㅎㅎ
# [긍정] 243 재미도 있고 작품성도 있고 ㅋ
# [긍정] 261 ㅋㅋㅋㅋㅋ은근히재미엇는데 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ나두초딩때봣어
# [긍정] 264 진쨔 재밌어 요ㅠㅠㅠ 정말정말
# [긍정] 275 중간에웃기고 잼게봤음 하얀말 귀여움ㅋㅋ
# [부정] 278 코끼리 여자는 왜나오고엔딩은 뭐지 진짜 엔딩은 뭔지아오 ㅋ 빡ㅋ쳐ㅋ
# [긍정] 308 재밌당 진짜 ㅋㅋ 시청률 낮은게 이해가 안되용
# [긍정] 321 트페 나와서줌 ㅋㅋ 아 갬빗말이에요 갬빗
# [긍정] 351 곽지민 매력터지고 얼굴 너무 이쁘다 내스탈 ㅠㅠ 곽지민짱
# [긍정] 358 평점이 너무 낮네 ㅋㅋㅋ쨋든 잼잇엇음 ㅋㅋㅋ
# [부정] 366 베드신말곤볼게없다ㅋㅋㅋ공포영화맞는건가
# [부정] 377 지 맞춤법이나 맞추고 이야기하쇼 ㅋㅋ 평점 점 미개수준 ㅋㅋㅋ
# [부정] 389 이문식 안내상 박준형 ㅋㅋ 탈선 재연영화네
# [부정] 391 아 진짜 이렇게 재미가 없을수가 ㅠㅠ
# [긍정] 420 역겨우면서 미워할수없는 악동들ㅋㅋ미치것다 기즈모 ㅜㅜ
# [부정] 421 재미없어 연기 넘 오글거려 ㅋㅋㅋ
# [긍정] 437 너무 너무 재미있어요 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# [긍정] 446 완전히 취향이라 넘 재밌게 봤다는 마지막 장면 최고ㅠ
# [긍정] 462 흥미진진 가수맞추는 재미가 쏠쏠합니다 ㅋㅋ아이유때 첨봤는데 넘 재미나여
# [긍정] 481 이런 감동 오랜만이다 이런 ㅠ
# [긍정] 509 심쿵심쿵 미치네요이수혁땜에 잠 못자겠어요ㅠ자꾸 아른거림ㅠ
# [긍정] 551 커서 보니까 이 영화 엄청 슬픈거엿써ㅠㅠㅠ게리올드만 멋잇드앙
# [부정] 567 연기가 상당히 거슬리지만 여주인공들이 이상하게 풋풋하네 ㅋ
# [부정] 570  년전에본영화 개봉했네 ㅋㅋ재미도 없는걸
# [긍정] 587 옴마야 린든형사 너무 좋다 ㅠㅠ
# [긍정] 608 마지막 진짜 달달하네 진심 재밌네 ㅋㅋ
# [긍정] 612 액션 정말 잘만들었더라 사토상 멋있다 ㅋㅋㅋㅋ 즐기기에 충분한 영화
# [긍정] 626 봐도봐도 너무 재미있는 못본신분들이 많턴데 꼭보세요ㅋㅋ
# [부정] 662 아 늘어지고 재미없네요 ㅠ 코믹도 스릴러도 아니야
# [긍정] 688 시간 가는줄 모르고 봤다 엄청 집중해서 보게됨 재밌음 ㅋㅋ 강추
# [부정] 709 왜 하필 주제가 고양이냐 ㅋㅋㅋㅋ 고양이 좋아하는 사람은 진짜 싫어하겠네
# [부정] 723 유사라가 왜 주연이지 ㅋㅋㅋ 카메오 급 출연 대박이삼
# [부정] 741 돈날렸다 공감좀 ㅋㅋ
# [긍정] 760 좋은 영화였음 강추 박소영 진짜 이쁘네 ㅠㅠ
# [부정] 769 ㅇㅇ 감독은 쌍용차한테 억청구해야할듯 ㅠㅠ
# [부정] 793 서유리의 변실금에서 딱 한번 피식하는 바람에 양심상 점 더 보탰다 ㅋ
# [긍정] 794 어릴때 보고 지금 다시 봐도 웃음을 머금는 영화 ㅋ
# [부정] 797 윤발성님 거기서 뭐해요 ㅠ아무리 봐도 이건 좀 아닌듯
# [긍정] 805 시사회에서 봤는데 정말 보는 내내 재밌고 감동이었습니다 진짜 재밌어요 ㅋㅋㅋ
# [긍정] 810 가면은 정말 충격적이었다 ㅋㅋㅋㅋㅋㅋㅋ
# [긍정]
# [긍정] 1265 에미 헐게 좋아요 진짜 보는 내내 뭐랄까 가슴이 들떠있어요 꼭보세욬ㅋㅋㅋ
# [긍정] 1267 완전 재밌었음 ㅠㅠㅠㅠ 잉 ㅠㅠ 끝나서 아쉽네요 ㅠㅠ
# [긍정] 1292 너무 따뜻한 영화 ㅠ ㅠ 보면서 울뻔
# [긍정] 1303 재밌을거같다 ㅎㅎ 보러가야겠네 ㅋㅋ
# [긍정] 1305 정말 최고 많이 웃은 영화 ㅋㅋ
# [긍정] 1312 요즘 또 보고 있는 중 언제봐도 재밌다는 ㅠㅠㅠ
# [긍정] 1322 숨겨진 수작 좀비물 좋아하시면 무조건 봐야함 ㅋㅋㅋ
# [긍정] 1325 마지막에 장국영과 오천련이 재회하는 신은 완전감동 ㅠㅠ
# [긍정] 1330 완전 훈훈하고 재밌기만 한데 ㅋㅋㅋ 평점이 왜이러지
# [긍정] 1336 크리스토퍼 월켄이 나온단다 ㅋㅋ
# [긍정] 1358  편 보다 재밌어요 테일러 로트너 나와서 깜놀 ㅋㅋ
# [긍정] 1365 최고최고 이런게 드라마 볼때마다 가슴시리다ㅠ작가 최고 배우들도 최고
# [긍정] 1371 완전 좋아요 ㅋㅋ 귀여워 니코
# [부정] 1383 낚인거 홧김에 점 드림 베일 짜증 ㅠㅠ
# [부정] 1385 그냥 한번 보세요 나만 시간낭비하기 아까우니까 ㅋㅋㅋㅋㅋㅋㅋㅋ
# [부정] 1396 재용이형 언제 엽기적인그녀같은거한번 더만들어줄꺼야 ㅠㅠ
# [긍정] 1404 이거 진짜 웃겼는데 ㅋㅋㅋ 투가이즈이후 최고로 웃은 한국영화ㅋㅋ
# [부정] 1406 모냐 이건 ㅋㅋㅋ 모제멋대로 나름의 예술이라면 예술이겠지 ㅋ
# [긍정] 1415 아직도 장면이새록새록기억나 ㅋㅋㅋ
# [긍정] 1417 와 수작인걸 마동석 좀 웃겼다 ㅋㅋ
# [부정] 1431 하두 유행해서 그냥 봣는대 에휴 ㅋㅋ 쓰렉
# [긍정] 1450 감동이다 ㅠㅠ 년도 작품이라니 대박
# [부정] 1452 진짜 심각하내 ㅋㅋcf보다 재미없네
# [긍정] 1470 김강우최고 저이런거처음써봐요 본방으로 꼭챙겨봄 ㅠ ㅠ 연기짱
# [긍정] 1475 너무 재밋엇는데 어디서 다운받지 ㅠㅠdvd라도 소장하고싶삼
# [긍정] 1476 이 드라마 진짜 재밌게 봤는데 ㅠㅠ 그래도 난 재밌었다
# [긍정] 1492 으아 친구들너무웃기다 ㅋㅋㅋㅋ남자도잘생기고 재밋다
# [긍정] 1497 완전 빵 터짐 ㅋㅋㅋ 자막으로 보세요
# [긍정] 1509 오 빠 ㅎㅎ꿀잼 ㅋㅋ 꼭보삼들
# [부정] 1510 처음부터 반지 던지면 될 걸 왜 마지막에 ㅋㅋ
# [긍정] 1525 고양이가 되게 귀엽던데 ㅋㅋ
# [부정] 1526 포스터 구경왔습니다 ㅋㅋㅋㅋㅋㅋ
# [긍정] 1578 저도 재밌게 봤는데 평점이 너무 낮네요ㅠ
# [긍정] 1616 명작이지 증말 ㅋㅋ이연걸영화중에 거의 최고
# [긍정] 1633 완전 시간내내 후덜덜 남자 분의 매력은 쩝니당 ㅠㅠㅠ
# [부정] 1634 개그맨 더빙만 안해도 참 좋았을텐데 진짜 몰입도 뚝뚝 떨어지고 ㅠㅠ
# [긍정] 1645 와우 정말 감동적인 영화입니닷 또보고싶어요 ㅠㅠ
# [긍정] 1648 중세물을 좋아하는 난 다른대작다지우고 이거소장 ㅋㅋ 킹왕짱으로 설명끝
# [긍정] 1652 최고에요 ㅠㅠ 몇번을봐도 감동의 ㅆ나미
# [긍정] 1658 내가 본 괴수영화 중 최고닼ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# [부정] 1663 다신 영화 만들지마쇼 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# [긍정] 1664 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ정말재밌고귀엽네욬ㅋㅋ
# [부정] 1665 불륜미화영화에 점이라니 ㅠㅠ
# [부정] 1677 진짜 어이없긴한데 ㅋㅋ나름 몰입해서 봤다 그래서 점줌
# [긍정] 1698 이영화가 어떻게 평점 점대냐 불후의 명작인데 ㅋㅋㅋ
# [긍정] 1702 드라마 너무 재밌어요ㅠㅠㅠ오늘 방송도 기대
# [긍정] 1712 재미만 있구만 ㅋㅋㅋ 볼만함
# [부정] 1713 공감대가 안맞는군 다른표현이 생각이 안난다 ㅜㅠ
# [긍정] 1720 어릴적 미친듯이 재밌게보았던영화 킴의매력이 듬뿍 ㅋ
# [긍정] 1763 레알 쩐닼ㅋㅋㅋㅋㅋㅋㅋㅋ잼있음
# [긍정] 1772 OST 너무 좋아서 계속 듣네요ㅠㅠ 특유의 파리나 집시 느낌이 너무 멋지다
# [긍정] 1782 전 이 영화 재밌던데 평점이 낮네요 ㅠㅠ
# [긍정] 1784 난 잼있던데 약간 유치하긴했지만 ㅋ
# [긍정] 1822 간지액션ㅠㅠ 이거 이후로 나온것들은 성룡 매력이 반감되었다
# [긍정] 1849 왜들그래요 이거내가 초딩때보고 반해서 계속챙겨봤던건데ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# [긍정] 1886 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ 굳 넘 재밋어영 여주인공도 넘 매력있구
# [긍정] 1895 김주혁 전도연 정말 잘어울려요 ㅡ ㅋㅋ
# [부정] 1910 멀리서 시사회 보러 달려갔는데 ㅠ 쫌실망했어요 ㅠ
# [부정] 1913 무당친구는 연기좀 괜찮은데 ㅋㅋ 감독이 진짜 ㅋㅋ개 발로만들었네 ㅋㅋ
# [긍정] 1920 티비에서 하는걸 우연히 봤는데 졸 잼있었다 ㅋㅋㅋㅋ 역시 아놀드
# [부정] 1924 진짜 재미없네 ㅋㅋㅋㅋ 배경과 옷과 배우들만 이쁘고
# [긍정] 1937 정말ㅠ중학교때보고 이십대후반이 다되가는데도ㅎㅎ또봗느 재밌네요
# [부정] 1946 니들이 말하는 예술이라는게 도대체 뭘 말하니 할아비가 폭탄 ㅋ 어이없다
# [긍정] 1954 나만 마지막에 운게 아니었구나 ㅠㅠ 다행이다
# [긍정] 1986 아 진심 너무 재밋곻 진후 너무 멋잇고 정수랑 진짜 잘 어울리는듯 ㅋㅋㅋ
# [긍정] 1987 보고싶다 어디서 구하나 ㅠㅠ
# [부정] 1991 졸고 또 졸고 리즈 왜 이런영화를 고른거야ㅠㅠ
# [긍정] 1993 제이슨 스타뎀의 논스톱 액션은 정말최고에다 너무 재미있었고 쩔었다 ㅋ
# [부정] 2003  억 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# [긍정] 2010 ㅋㅋㅋㅋㅋ 근데 진짜 재밌어요
# [부정] 2059 우왕 최악이야ㅠㅠ 이런 엉뚱한 스토리전개
# [긍정] 2067  년에 이걸 극장에서 봤을 사람들이 너무 부럽다 ㅠㅠ 정말 충격이였을듯
# [부정] 2068 정말 재미없어요 ㅠ 진심으로
# [부정] 2075 괜히봣어 괜히봤어 유치 짬뽕 로맨쓰 ㅋㅋ
# [부정] 2091 벌집을발로 왜 찾을까요 궁굼하네 ㅋ
# [부정] 2136 마지막 부분 떄문에 점추가 한다 ㅋㅋㅋㅋ 이거원 인간극장 보는줄 알았다
# [긍정] 2155 아 마이클 ㅠㅠㅠㅠ 당신의 자리가 참 크군요 ㅠㅠ
# [부정] 2161 계속 끊기는건 왜죠 ㅋㅋㅋ 씹노잼
# [긍정] 2178 주인공들이 너무 귀여워 보였다는ㅋㅋ 재밌고 유쾌한 로맨틱 코미디 영화
# [긍정] 2192  년전에 나도 그럤는데 ㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# [긍정] 2212 어쩜 사랑이 이럴수가 있음 ㅠㅠㅠ
# [긍정] 2214 김정태 진짜 웃기다 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# [부정] 2216 다알바생임 나 완전 잼없게 봤는데 ㅋㅋ
# [긍정] 2229 진짜 누가 이 영화를 평가할수있을까ㅠㅠ
# [긍정] 2239 정말 최고였는데 마지막이 이련결말 싫다 ㅠ
# [긍정] 2252 김강우라는 배우를 알게된작품 연기잘하네요 박용하도물론굿 잘봤음ㅋㅋ
# [긍정] 2267 완전 개잼 졸잼 핵꿀잼이다 ㅋㅋㅋ
# [부정] 2279 마지막개애바인듯 ㅋㅋ 마음은 점을주고싶은데그게안돼서
# [부정] 2297 이런것도 영화라고 최악의 영화 절대비디오도 보지말라 ㅠ
# [부정] 2299 ㅋㅋㅋ 좀비가 주먹질을 하네 ㅋㅋㅋㅋ 긴장감도 없고 ㅋㅋㅋㅋ
# [긍정] 2317 웃김ㅋㅋ진짜ㅋㅋㅋㅋ피아노 공연장에서 남자 주인공ㅋㅋㅋ골때리는 영화임
# [부정] 2325 영화를 보면서 스트레스 받고 싶은 사람만 보셈 ㅋㅋㅋ
# [긍정] 2326 감동반전이라 더 의미있었음ㅠㅠ방금봤는데 계속 슬프다
# [긍정] 2327 정말 감동적이네요 ㅠㅠ 진짜 재미있어요 안보면 후회할 그런영화
# [긍정] 2345 보아의재발견ㅠㅠ 임시완의재발견 스토리는딱여자들이좋아할만한재밌는드라마인듯
# [긍정] 2349 ㅋㅋㅋ내용도 게안코 잼있네요
# [부정] 2357 솔직히 네티즌 평점 쓰는 시간 조차 아까울 뿐 ㅋㅋㅋㅋㅋ
# [긍정] 2358 이거 학교에서 음악쌤이 보여줬는데 너무재밌어요ㅋㅋㅋ
# [부정] 2409 나의 힘으로 이 영화의 평점은 떨어졌도다 ㅋㅋㅋ
# [부정] 2414 곽부성 물가지고 장난치는게 간지였는데 ㅋㅋ풍운 스토리 안습
# [부정] 2416  점 주고싶네요 쓰레기 ㅠㅠ 내 시간을 낭비했어
# [긍정] 2427 저팔계얼굴은 년이 넘게지난 지금봐도 기억난다 ㅋㅋ 이거 완전 잼있음
# [부정] 2454 약혼자 넘 불쌍하고 공주는 철이없는거같아요ㅠㅠ아이들이 보기엔 좋을듯
# [긍정] 2459 이거보면 무술배우고싶은 욕망이 쑥쑥 ㅋㅋㅋㅋㅋㅋㅋㅋ재밋엇다
# [긍정] 2473 생각없이보면 존나 욱긴영환데 평점 왜이러냐 ㅋㅋㅋ
# [긍정] 2478 good good good very good 전작도 봐야겠는데 ㅋㅋ
# [긍정] 2482 아 개무서워 스릴쩔어여ㅠㅠ
# [부정] 2511 이영화 보지 말라는 소리뿐이넹 ㅠ ㅠ
# [긍정] 2520 난 괜찮던데 평점 엄청 안좋내욬ㅋㅋ 저는 재미있게봄
# [긍정] 2527 굳굳ㅠㅠ 중국어 배우고 싶다 생각한 영화
# [긍정] 2545 초딩때 진짜 재밌게 봤던 영화 ㅋㅋ
# [부정] 2547 푸하하하하하ㅏㅎ하ㅏㅎ 머리봐 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ좀짱인듯 ㅋㅋㅋ
# [긍정] 2560 마지막에 비둘기 아줌마와 우정 완전 감동 ㅠ ㅠ
# [부정] 2573 내가 평점을 남기다니 ㅋㅋㅋ cg가 만화같어 ㅋㅋㅋㅋ
# [긍정] 2585 완전 감동했어요 ㅠㅠ 참 깊은 사랑 이야기
# [긍정] 2622 ㅋㅋㅋ여자분 몸매가 아주 쩜ㅋㅋ 액션연기도 잘하고 추천
# [긍정] 2633 골때리네 ㅋㅋ신민아 진짜 귀엽게 나옴
# [긍정] 2635 에스비에스서 해줘서 봤는데 장난아니게 웃긴다 쵝오다 ㅋㅋㅋ
# [긍정] 2655 완전 재미있음 추천 ㅠㅠ 생텀 화이팅
# [긍정] 2666 기억이 가물가물 하지만 캐스퍼는 귀여웠당ㅋㅋㅋㅋ또볼까
# [긍정] 2674 펭귄 때문에 웃겨 죽겟내요 ㅋㅋㅋㅋ 아 너무 귀엽다는 ㅋㅋㅋ
# [부정] 2692 공짜로 봤는데도 승질이 나더군 ㅋ
# [긍정] 2702 다른 사람은 몰라도 난 재밌다 ㅋ
# [긍정] 2709 아 다시보고 싶은데 ㅠㅠ 명작이네여
# [긍정] 2711 엔딩이 너무좋았음 흔한 클리셰가 아니라 예측하기도 어렵고 진짜 좋았음 ㅠㅠ
# [긍정] 2721 폴워커가 사라지고 갑자기 갑툭튀가 등장했지만 그래도 꽤 재밋엇음ㅋㅋ
# [긍정] 2736 드디어찾았네ㅠㅠㅠ어릴때본것중에 젤 재밌던
# [부정] 2741 졸렸어요 ㅠ 침삼키기 민망했ㅇ음
# [긍정] 2747  년씨짘ㅋㅋㅋㅋㅋㅋ나올때마닼ㅋㅋㅋㅋㅋㅋ으헠ㅋㅋㅋ근데재밌어요
# [긍정] 2749 오늘아프리카에서이영화를봤다너무가슴이짠했다전우애대한감동 ㅠ ㅠ
# [긍정] 2755 금방봤는데 재밌기만 하구만 ㅋㅋ
# [긍정] 2776 이름 모르고 중 때 본 영화 고 때 이름을 알게 되었네요 ㅋㅋ
# [부정] 2777 공포영화인데 왜 웃음이 나오냐 ㅋㅋ
# [긍정] 2791 ㅋㅋㅋ아이거마지막까지욀케황당하지ㅋㅋㅋ스토리만봐도 점은줘야할영화임ㅋㅋ
# [부정] 2801 진짜 파라노말 시리즈중에 쓰레기다진짜ㅋㅋㅋㅋ결말또 뭐어쩌자고 돈아깝
# [긍정] 2804 우왕 ㅋㅋㅋ 완전 대단해요 반전
# [긍정] 2831 이 영화 추억하는 사람들이 은근히 많구만ㅠㅠ
# [긍정] 2832 재밌는뎁 평점왜이럼 ㅋㅋㅋㅋ
# [긍정] 2835 버지니아 울프는 천재고 틸다 스윈튼의 매력에 빠져듬 ㅋㅋ
# [긍정] 2851 멜로라기 보단 판타지에 가깝구마 ㅋㅋ 하지만 이런 영화 참 좋다 ㅋㅋ
# [긍정] 2858 조기종영이 너무 아쉬운 드라마 ㅠㅠㅠㅠ
# [긍정] 2865 재밌었음 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 아 가브 귀여웡 ㅋㅋ
# [부정] 2871 이선진 완또네요 ㅋㅋㅋㅋ 자기가 로보트 인줄아네 미췬
# [긍정] 2877 역시 트레이 파커는 나를 실망 시키지 않았다 음악과 그의 연기도 굿 ㅋ
# [긍정] 2903 꿀꿀개꿀잼 정자매겁나게이쁘다ㅠㅠ
# [긍정] 2906 ㅠㅠ 마지막에 왜캐 눈물이 쏟아지는지 잘봤네여
# [긍정] 2920 평점왜케낮지 이거보고싶어서계속찾는중 ㅠㅠ
# [부정] 2938 재미없어 ㅋㅋㅋㅋㅋㅋㅋ 너무뻔함
# [부정] 2947 호평만겁나게 많어 ㅋㅋ 칭찬게시판인가
# [부정] 2952 이거보고 잠이 솔솔 왔는데 이딴 쓰레기프로는 폐지 잘했음 ㅋㅋㅋ
# [긍정] 2958 로안앳킨슨의 미스터빈 어리버리 연기가 돋보인 영화 속편도 잼있음ㅋㅋ
# [부정] 2961 쓰레기더ㅏㅋㅋㅋㅋㅋㅋㅋㅋㅋ돈주고봣엇는데내돈돌려내
# [부정] 2963 그닥 재미없는데 생각보다 높군 ㅋㅋ
# [긍정] 2970 케이블에서 봤는데 진짜 재밌네요 ㅋㅋ 저스틴 롱도 좋고
# [긍정] 2977 ㅠㅠ수트어쩔거에요 ㅠ 정말 재밌었어요 ㅎㅎ
# [긍정] 2996 옛날에 mbc에서 자주해주던 영화 잼났었던 ㅋ
# [부정] 3000 일본가서 저딴거 찍고싶냐 한국와라ㅋ
# [긍정] 3009 ㅋㅋㅋ 초등학교때보고 성인이되서도 재밌게보는영화 상상력이대단하다 ㅋㅋㅋ
# [부정] 3010 ㅋㅋㅋㅋ 웃음밖엔
# [긍정] 3012 왜 죽어야만 했을까 ㅠㅠ너무 잔잔하면서 가혹한 영화
# [긍정] 3047 박정민을 다시보게된 영화 ㅋㅋㅋㅋ연기 감동임
# [부정] 3054  재미없음 스토리 ㅠㅠ
# [긍정] 3064 뭔가 여운이남는 영화였어요 추천드립니다 ㅠ
# [긍정] 3072 완전 재밋었는데ㅠㅠ조윤희연기쩌럿음
# [부정] 3077 솔직히 웃김 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ
# [긍정] 3083 오랜만에 스릴러다 더 재미 있었네 ㅋㅋ
# [부정] 3106 감독은 의도도 안한거가지고 지들멋대로 해석하고 명작으로 치켜세움 ㅋㅋㅋ
# [긍정] 3119  살때인가티비에서본거같은데 ㅠㅠ어렸을때엄청울면서봤던영화
# [부정] 3121 뒤로갈수록 점점ㅋ 재미없어졌음ㅋ
# [부정] 3136 어쩌자고 이런 영화를 킬링타임도 안된다 ㅛ ㅋ
# [긍정] 3142 이거ㅋㅋ옜날에찐짜많이봤는데ㅋㅋㅋㅋㅋㅋㅋ
# [긍정] 3159 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ귀엽닥
# [긍정] 3167 ㅋㅋㅋ내 취향이네 잼나겠당
# [부정] 3188 재밌다는 사람들은 뭐지 ㅋㅋ 완전 지루하던데
# [부정] 3197 유치의 끝자락ㅋㅋㅋㅋㅋㅋ어린이동화ㅋㅋㅋ
# [긍정] 3207 아너무좋다ㅠㅠㅠ한태희ㅠㅠ 사라ㅠㅠ
# [부정] 3210 이새 낀 뭐 인간이 아니냐 ㅋㅋ 스릴이라고는 찾아볼수없는 허접한 삼류영화
# [긍정] 3213 갓지현 년지났는데 똑같구나 ㅋㅋ
# [부정] 3226 포장을 너무 했음 ㅋㅋㅋ 이탈리아에도 한국 건달영화가 존재하는구나 ㅋㅋ
# [긍정] 3231 어릴때보고 지금다시봐도 재밌어요ㅋㅋ
# [긍정] 3236 시즌 까지 본상태 잼네요 ㅋㅋ 까지 달리는거다
# [부정] 3264 별걸 없던데 뭔 일본내 상영 금지 개 웃기네 ㅋㅋ
# [긍정] 3278 주변애들 후뢰시맨 볼 때 난 이거봤다 ㅋㅋ 내스타일 진짜 재미있게 봤음
# [부정] 3292 뭐가 있겠지 있겠지 하면서끝까지 봤는데 ㅋ 이건 좀 심하네
# [긍정] 3294 이거 돼게 재미있는데 ㅋㄷㅋㄷ
# [부정] 3304 EBS보는게 더 잼있다 ㅋㅋㅋ죤나 시간아까워ㅋㅋ
# [부정] 3320 원작을 망친 마누언제작비의 일본한국합작 ㅋㅋㅋㅋㅋㅋ
# [긍정] 3327 근데 막판에 왠 로봇이지 ㅋㅋ
# [긍정] 3338 존내멋잇어 ㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠㅠ
# [긍정] 3339 아무생각없이 봤는데 가슴에 남는영화ㅠ ㅠ
# [부정] 3341 현명 노민우 암유발자 작가가 싫다ㅠ
# [부정] 3358 진짜 궁금해서 그러는디 원래 허리케인이 폭탄하나면 없어짐 ㅋㅋ
# [긍정] 3370 슬픈영화보고 우울해서 이거봤는데 빵빵터짐ㅋㅋㅋ
# [긍정] 3396 재밌어요 남미 특히 쿠바의 독특한 문화를 느낄 수 있었음 노래도 신나고ㅋ
# [긍정] 3438 완전 짱임 한번 보면 폐인됨 ㅋㅋㅋ
# [긍정] 3439 어릴 적 기차화장실씬은 충격 이였다 ㅋㅋ
# [긍정] 3441 재미있음 짱ㅋㅎ 보다 재밌음
# [긍정] 3442 재밌든데요 ㅎㅎ 그냥 뭐 이연걸 보기엔 좋은 영화 ㅋㅋㅋ
# [긍정] 3447 오늘 이 영화를 봤는대 정말 재미있다 ㅋㅋ
# [긍정] 3455 아진짜 너무둘다 사랑스럽다 ㅋㅋㅋㅋ 요근래 본 로맨틱코미디중 최고최고
# [긍정] 3468 저도 재미있게봤어요 추천ㅋㅋㅋㅋ
# [부정] 3470 별로 인거 같음 시간이 아까움ㅠㅠ 기억에도 안남을거 같고
# [부정] 3481 별 개줄수는 없는건가요 ㅋㅋ
# [긍정] 3484 너므 재밌어요 가디도 귀엽고 레바도 귀여움ㅋㅋ
# [긍정] 3493 인생을 바꿔버린 드라마랄까 ㅋ
# [부정] 3504 너무 작위적인 스토리 전개 실망스러운 영화ㅠ
# [긍정] 3507 초딩때 봤는데 진짜 짱 ㅋㅋㅋㅋ
# [부정] 3510 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ 포스터만 무서움
# [부정] 3538 ㅋㅋ첨으로 네이버평점에 동의한다 ㅅㅂ 그냥 초등학생들이 보면되겠다
# [긍정] 3540 배우들 너무 연기 잘해요 ㅠㅠ
# [긍정] 3545 봤는데 그래도 봐도봐도 보고싶어 무료가 있었으면 이제 있어도 될뜻싶기에ㅋ
# [긍정] 3574 살짝더러운부분이있음ㅋㅋ그래도재밌음ㅋㅋㅋ
# [긍정] 3578 특이한 그래픽 생각보다 잼있네요 ㅋ
# [긍정] 3581 명작이다 ㅋㅋㅋ근데 대사들이 너무 중 병이얔ㅋㅋ
# [긍정] 3599  분동안 조금도 지루할 틈이 없는 사건의 연속ㅋ
# [부정] 3607  참나 ㅠㅠ 너무 기대했음
# [긍정] 3617 애기너무귀여움ㅠ 그리고너무불쌍함ㅠ
# [긍정] 3624 굿 잼게 봤네 ㅋㅋ아주 좋아요
# [부정] 3631 역대 최고의막장드라마 ㅋㅋㅋ사랑의전쟁인지 조선선박 성공드라마인지 ㅋㅋㅋㅋ
# [긍정] 3643 ㅋㅋㅋㅋ재밌다 이런 영화들 많이 보고 싶다
# [긍정] 3660 어렸을때 본 충격의 영화ㅠㅜ 다시 보고싶다ㅠㅠㅠ
# [긍정] 3670 간만에 재밌는 로코 발견 ㅋㅋㅋㅋ 웃으면서 재미나게 봅니다 ㅋㅋㅋㅋㅋㅋ 굿
# [긍정] 3676 야밤에 완전 깔깔대고 웃었다 정신없고 재밌음 ㅋㅋ
# [긍정] 3685 저기서 노랑 회색 줄무늬 여자 반희라는 사람이 제일 괜찮음 ㅋㅋ
# [긍정] 3705 애절한 둘의 사랑 ㅠㅠ 사랑영화임 이건
# [부정] 3729 재밌긴 했는데 솔직히 개사기인듯ㅋㅋ 방탄복보다 배강한 피부라닠ㅋ
# [긍정] 3748 소재부터 색달라서 끌렸던것같구요 정말 볼수록 흥미진진해요ㅋㅋ
# [긍정] 3766 색다른 발상 ㅋㅋ 그리고 꽤 재미있었음
# [부정] 3808 ㅋㅋㅋ 액션도 그냥저냥 내용은 개시망 연출도 망
# [긍정] 3810 이런 영화를 만들어주셔서 감사합니다ㅠㅠ
# [긍정] 3819 진짜 너무재밋엇음 울음ㅠ 그리궁 특히 태범이야기가재잇엇음
# [부정] 3846 전개가 진짜 ㅋㅋㅋ 할말이없다
# [긍정] 3867 너무 감동적이엇어요ㅠ 미국가고싶네요 I LOVE YOU USA
# [부정] 3873 초단순하고 재미도 없는 내용을 다시 감기로 길게 늘어뜨려놓았네 ㅋㅋ
# [긍정] 3877 ㅋㅋㅋㅋㅋ진짜 짱임ㅋㅋㅋㅋㅋ거침없이 하이킥과 뉴논은 정말 최고다
# [긍정] 3895 존잼 그와중에 마틴 졸귀ㅋㅋㅋ
# [긍정] 3914 난 해피엔딩이 좋은데 ㅠㅠ 너무 슬픈영화다ㅜㅜ
# [긍정] 3925 웬만한 한국영화보다 낮네 ㅋㅋㅋ
# [긍정] 3938 배우들 연기력도 좋고 점점 기대된다는 ㅋㅋ
# [긍정] 3939 진찌 너무 너무 재밌고 나리미야 히로키 짱 귀여워ㅋㅋ
# [부정] 3942 평점 더내리고싶은데 괜히 원주율 지키고싶어진다 쓰레기영화ㅠㅠㅠㄱㄱㄱ
# [긍정] 3943 다시 보고 와야겠네요ㅋㅋㅋ재밌었는데ㅋㅋㅋㅋ
# [부정] 3969 이것도아깝다 ㅡㅡ 돈 개아까움 ㅋㅋㅋㅋㅋ 잤음
# [긍정] 3972 평범하지않은 사랑 ㅋㅋ 조쉬짱
# [긍정] 3984 감동을 얼만큼 받았냐로만 봤을 땐 내가 봤던 지브리 작품 중에 제일이었음ㅠ
# [긍정] 3986 희대의 명작 ㅠㅠ ㅠ 절대 후회하지 않는 영화
# [부정] 3988 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ네이버 평점도 믿을수있데 ㅋㅋㅋ
# [부정] 4012 OOO 매니아들 여기 다 모였네 ㅋㅋㅋ
# [부정] 4022 캐 형님을 일케 어리버리하게 만들수도 있군하 캐안습ㅠ
# [긍정] 4025 최고 이 말 외엔 뭐가 어울릴지 ㅠ시즌 마지막 너무 감동적이예요
# [긍정] 4057 아 효도 해야겠네 ㅠㅠ
# [긍정] 4064 진짜 번봐도안질려옄ㅋㅋㅋㅋㅋㅋㅋ
# [부정] 4067 아놔 견자단 한쿡어 때문에 감정이입이 안돼 ㅠ
# [긍정] 4076 김영광때문에봣는데 제가봤던드라마중에제일재밋엇어요ㅜㅜ진심ㅠㅠ
# [긍정] 4079 완전 재밌네용 ㅁ ㅋㅋ 유치할 것 같아서 무시했었는데 완전 재미써용ㅋㅋ
# [부정] 4082 여자친구랑 봐서 ㅠㅠㅠㅠㅠㅠㅠ
# [부정] 4105 억지감동 억지연기 진짜 류다 그나마 우리 귀요미 효진의 발견ㅋㅋ
# [부정] 4138 제목 센스 끝내주는 감독 ㅋㅋ
# [긍정] 4141 이거 안보면 초 후회합니다 초강추 양채니 미모는 와우 ㅋㅋ
# [긍정] 4158 이선우 이선우 이선우 잊지못햐 ㅠㅠ 보고싶다 다시 한버뉴ㅠ
# [긍정] 4162 재밌구먼 난 이거 잊을수없어 ㅋㅋ
# [긍정] 4184 기억도 잘 안날 정도로 어릴때 봤지만 엄청 좋아했던 만화ㅋㅋ
# [긍정] 4189 최고에 액션 정말 잼있게 봤었음 어릴때 ㅋ
# [부정] 4190 이특집 누가 기획했나요 개노잼 ㅋㅋ진짜노잼
# [긍정] 4192 ㅋㅋㅋㅋㅋ나는 마지막때 성우가 제일 웃겼음ㅋㅋㅋㅋㅋㅋㅋ센스돋넼ㅋㅋㅋㅋㅋ
# [부정] 4197 잔인하기도 하고 무서웠어요ㅠ탑은 멋있더라구요
# [긍정] 4204 비가스 루나의 재능 스페인식 유머의 절정 까지는 안돼도 꽤 웃겼음 ㅋㅋ
# [긍정] 4209 최고에여 ㅠㅠ 명작이네여
# [긍정] 4224 백묘팬임ㅋ아아새콤달콤베이커리원작인데둘다재밋어요 정일우쨔응 신고
# [긍정] 4226 일일드라마가 뭐 이렇게 재밌나 ㅋㅋ 금순이 의지 정말 존경스럽고
# [긍정] 4240 미친 개조움 ㅋㅋㅋ오늘꺼 존잼 ㅋㅋㅋㅋㅋ
# [긍정] 4251 김슬기때문에본다 너무너무귀엽고 연기두잘하구ㅋㅋ
# [부정] 4252  천원내고 이거보라고 ㅋㅋ 점들전부 ㅋ뒹촌가 ㅋ
# [긍정] 4255 아진심두시간동안계속욺ㅠㅠㅠ짱이다
# [부정] 4258 너무 졸립다 ㅋ 수면제도 아니고 ㅋ
# [부정] 4270 기대한 내가 바보 인건가 점은 안되네ㅋ
# [긍정] 4285 ㄲ ㅑ 악 잼있어 ㅋㅋㅋ
# [부정] 4304 취권은 아주 쬐끔 나옴 ㅋㅋㅋ
# [긍정] 4313 짱웃긴데 왜 점수가 이렇게 박하지 ㅠㅠ
# [부정] 4332 너무 하네 영화가 진짜 ㅋㅋㅋㅋ 류영화 보다 더 못한 류영화
# [긍정] 4352 제목이 왜 서스페리아지 재밋엇다ㅋㅋ
# [긍정] 4355 너무 슬퍼요ㅠㅠ 죽음을 초월한 사랑
# [긍정] 4359 영화의 기운자체가 웃기다 ㅋㅋㅋㅋ 로다주 때문에 배꼽 잡았다 ㅋㅋㅋㅋ
# [긍정] 4360 악 ㅋㅋ제리케이다 멋지다
# [부정] 4378 보다가 너무 빡쳐서끔볼만한건 갱의 통 부바지 ㅋ
# [부정] 4430 ㅋㅋㅋㅋ지금보니깐좀그렇당ㅠㅠㅠㅠ
# [긍정] 4437 명작입니다ㅠㅠ 진짜 강추인데 평점 왜이러지
# [부정] 4453 줄거리가 영화내용 전부네 ㅋㅋㅋ
# [긍정] 4470 큰스크린으로 볼 수 있어서 행복근데 전국개봉이 아닌것은 아쉽 ㅠ
# [긍정] 4495 임주환 씨 연기도 잘하고 넘 멋있네요 애절애절해ㅠ
# [긍정] 4497 인생영화임 ㅠㅠ진짜 OO명곡 완전 많아여
# [부정] 4499 간만에 봤는데 별로 재미는 없음ㅋ
# [긍정] 4538 생각나 ㅋㅋㅋㅋ 초딩때 신기했었는데 벌써 년전 ㅋㅋㅋ
# [긍정] 4545  화보고 그냥 코미디인줄 알았는데 나름 감동도 있음 꼭봐라 두번봐라 ㅋ
# [부정] 4553 이거다른감독이더시만들면안됨 ㅋ
# [부정] 4561 유체이탈 경험자로써 긴장감제로 공감도 전혀안되고 핵노잼 ㅠㅠ
# [부정] 4562 그저 그래여ㅋ 근데 평점이 너무 높아서ㅠ
# [긍정] 4565 우와 샤크보이가 테일러였다니 언제이렇게 큰거야ㅋㅋㅋㅋㅋㅋㅋ
# [부정] 4584 솔직히 지금 보기엔 많이 유치하지 ㅋㅋ 그당시니까 대박소리나오는거지
# [긍정] 4585 성공한 작전인데 보는 내내 가슴졸여 미치는줄알았다 ㅋㅋ
# [부정] 4597 팬더가악당ㅋ자기네나라동물로미국이영화흥행했다고빡쳐서짝퉁만든듯하여간쭝궈레알ㅄ
# [부정] 4621 결방하지말아요ㅠ 일주일기다렷는데 이게무ㅏ죠
# [긍정] 4632 완전 대박 ㅠㅠ 후회없는 영화에요 꺅꺅꺅
# [부정] 4646 무지개여인 찾는 지루한 여정 ㅠㅠㅠ
# [긍정] 4684 골룸에겐 아쉬운데로 리벨룽겐의 반지를 ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ ㅋ
# [긍정] 4686 딸바보 니콜라스 케이지 ㅠㅠ
# [긍정] 4690 아진차 한회한회를 거듭할수록 너무 재밋다는 미치겟음ㅠ
# [긍정] 4718 너무아쉬워요ㅠㅠㅠ사랑해요 응급남녀
# [긍정] 4730 보고서 한없이 울었습니다 ㅠㅠ
# [긍정] 4743 앤드류를 안아주고 싶었던 ㅠㅠ씁쓸한 영화였어요 전 정말 재미있게 봤습니다
# [부정] 4752 정말 어처구니없는 ㅄ같은영화 무슨 좀비영화도아니고 총맞고 살아나질않나 ㅋㅋ
# [부정] 4753 머 이런 액션영화가 있어 ㅡㅡ 내 아까운 시간 ㅠㅠ
# [긍정] 4764 나탈리포트만 연기가 영화 반은 살린듯 ㅋ 조지 넘 불쌍 ㅠㅠ
# [부정] 4783 이건 공포가 아니고 코메디 ㅋㅋㅋ피식
# [긍정] 4792 귀여워 동심을파괴하는게너무좋다 ㅋㅋㅋ
# [긍정] 4794 재밌다 ㅋㅋ 영화가 전체적으로 센스있네
# [부정] 4797 아 진짜 재미없다 여자애가 범인임ㅋㅋㅋ
# [부정] 4819 조금의 주저함도 없이 올해 본 영화중 최악으로 임명합니다 돈아까워ㅠㅠ
# [긍정] 4823 처음본 나이트메어시리즈 따분한 밤시간에 잠 확달아나게 하는군ㅋㅋ
# [부정] 4830 막장 하지만 쓰레기는 아니다 노래는 중독 ㅋ
# [긍정] 4839 최고의애니메이션 번정도봣는데볼때마다눈물이난다ㅠㅠ
# [부정] 4846 아랫분들 너무 평점 이 후한거아님 어떻케 이 영화가 점이야ㅋ
# [부정] 4851 재미도없고 감동도없고 아무내용이없네요이게 무슨 영화에요 대체 ㅋㅋㅋ
# [부정] 4853 예술에 대한 무지함이 죄겠죠 ㅠ 이해 못하곤 창피한 이 기분
# [긍정] 4855 사무앨 잭슨이랑 브루스월리스 연기가 너무 웃기고 재밌었다ㅋㅋ
# [부정] 4878 지루해서 끝에 분은 그냥 넘겨버렸어요ㅋㅋ 그냥 여배우가 매력적인 영화
# [긍정] 4881 초반부를 제일 재밌게 봤음ㅋㅋ 그리고 짐캐리는 웃을때 참 멋있다
# [긍정] 4882 ebs에서 해준 영화 잠깐 볼려고했는데 끝까지 다봄 ㅋㅋ 재밌네요
# [긍정] 4910 정말 담백하게 공감이 가네요 안타까울따름ㅠ
# [긍정] 4923 전 초딩인데도 재밌게 봤음 ㅋㅋ 김선아 짱
# [긍정] 4942 일본드라마중의 최고의 드라마 ㅋㅋ
# [긍정] 4947 신문지를 쓰고 날으는 인은 아름다웠다 ㅋㅋㅋㅋ
# [부정] 4954 보지마세요 ㅠㅠ벗어도 안야해요ㅠㅠ
# [긍정] 4968 대박ㅜㅜ 이렇게 끝내다니 시즌 나올때까지 또기다려야겠구나ㅠㅠ
# [긍정] 4987 마지막에 진짜 좋았는뎅 내가슴속에 영원히 담겨져 있슴 ㅠㅠ 완죤 잼났슴 ㅠㅠ
# [부정] 4988 연기 드럽게 못하네 진짜 ㅋㅋㅋㅋㅋㅋ 이쁜척하려고 영화 찍냐
# "ㅋ"이 포함된 부정리뷰 수: 105
# "ㅋ"이 포함된 긍정리뷰 수: 182
# "ㅠ"가 포함된 부정리뷰 수: 40
# "ㅠ"가 포함된 긍정리뷰 수: 95

# %%
cnt_z =0
cnt_b = 0
for s in test.document:
    if 'ㅋ' in s:
        cnt_z +=1
    elif 'ㅠ' in s:
        cnt_b +=1
        
print(f'"ㅋ"이 포함된 리뷰 수: {cnt_z}')
print(f'"ㅠ"가 포함된 리뷰 수: {cnt_b}')
# Out:
# "ㅋ"이 포함된 리뷰 수: 302
# "ㅠ"가 포함된 리뷰 수: 105

# %% [markdown]
# # 맞춤법 교정 라이브러리
# ## Py-Hanspell
# * 설치방법
# ```
# git clone https://github.com/ssut/py-hanspell
# cd py-hanspell
# python setup.py install
# ```
#
# ## PyKoSpacing
# * 띄어쓰기 라이브러리

# %%
train.document[3142]
# Out:
# '이거ㅋㅋ옜날에찐짜많이봤는데ㅋㅋㅋㅋㅋㅋㅋ'

# %%
spck = spell_checker.check(train.document[3142])
spck.checked
# Out:
# '이거ㅋㅋ옜날에찐짜많이봤는데ㅋㅋㅋㅋㅋㅋㅋ'

# %%
temp = '이거 옜날에찐짜많이봤는데'

# %%
spell_checker.check(temp).checked
# Out:
# '이거 옛날에 진짜 많이 봤는데'

# %%
spck = spell_checker.check(temp)
spck.checked
# Out:
# '이거 옛날에 진짜 많이 봤는데'

# %% [markdown]
# * 자음이나 모음이 섞여있을 경우 맞춤법 검사가 제대로 동작하지 않음.
# * 자음과 모음만으로 이루어진 리뷰는 없고, 테스트셋에 있더라도 훈련에 없기 때문에 판단하는 것은 어렵다고 생각하여 제거하기로 결정

# %%
okt = Okt()
def preprocessing(df):
    df['document'] = df.document.apply(lambda x : re.sub(r'[^0-9a-zA-Zㅏ-ㅣ가-힣]+', ' ', x).strip())
    df['spell_ck'] = df.document.apply(lambda x : spell_checker.check(x).checked)
    df['tokenized_stem'] = df.document.apply(lambda x : ' '.join(okt.morphs(x, stem=True)))
    df['tokenized_stem2'] = df.spell_ck.apply(lambda x : ' '.join(okt.morphs(x, stem=True)))

    return df

# %%
X_train = train['tokenized_stem2'].values
y_train = train['label'].values
X_test = test['tokenized_stem2'].values

tfidf = TfidfVectorizer(ngram_range=(1,2),
                       min_df=3,
                       max_df=0.9,
                       tokenizer=okt.morphs,
                       token_pattern=None)
tfidf.fit(X_train)
X_train_okt = tfidf.transform(X_train)
X_test_okt = tfidf.transform(X_test)

sgd = SGDClassifier(loss='log', random_state=SEED)
param_dist = {'alpha': loguniform(0.0001, 100.0)}
rsv_okt = RandomizedSearchCV(estimator=sgd, param_distributions=param_dist,
                            n_iter=50, random_state=SEED, verbose=1)
rsv_okt.fit(X_train_okt, y_train)

print(rsv_okt.best_score_)
print(rsv_okt.best_params_)
# Out:
# Fitting 5 folds for each of 50 candidates, totalling 250 fits
# 0.8713999999999998
# {'alpha': 0.00014355463635694167}

# %% [markdown]
# # 맞춤법 교정 전
# * rsv_okt.best_score_: 0.8664
# * rsv_okt.best_params_: 'alpha': 0.00014355463635694167
#
# # 맞춤법 교정 후
# * rsv_okt.best_score_: 0.8713999999999998
# * rsv_okt.best_params_: 'alpha': 0.00014355463635694167

# %%
pred = rsv_okt.predict(X_test_okt)
pred
# Out:
# array([1, 1, 0, ..., 1, 0, 1], dtype=int64)

# %%
submission['label']=pred
submission.to_csv('submission.csv', index=False)

# %% [markdown]
# # 영어 리뷰

# %%
onlyEng =[]
for i, s in enumerate(train.document):
    if len(re.sub(r'[a-zA-Z ]+', '', s))<1:
        print('[긍정]' if train.loc[i+1, 'label']==1 else '[부정]', i+1, s)
        onlyEng.append(s)
print(f'영어로만 쓰여진 리뷰 수:{len(onlyEng)}')
# Out:
# [긍정] 160 very very very good
# [긍정] 660 revenge is sweet
# [긍정] 722 It gets better and better as it goes on D
# [긍정] 2467 divorce D I V O R C E
# [긍정] 2718 Miranda Cosgrove A BEST
# [긍정] 3694 It s a strange film isn t it
# [긍정] 4127 produced be Christopher Nolan
# [긍정] 4148 Thuth is out there
# [긍정] 4766 No comparison superb
# 영어로만 쓰여진 리뷰 수:9

# %% [markdown]
# 영어로 이루어진 리뷰는 모두 긍정리뷰

# %%
onlyEng =[]
for i,s in enumerate(test.document):
    if len(re.sub(r'[a-zA-Z ]+', '', s))<1:
        print(i+1,s)
        onlyEng.append(i)
print(f'영어로만 쓰여진 리뷰 수:{len(onlyEng)}')
# Out:
# 3 Childhood fantasy
# 459 Amazing discovery
# 663 LIFE DOG GREAT
# 757 It was very good
# 1024 You saw what you wanted to see
# 1314 thank you very good job
# 1326 It was a nice super duper
# 1387 Best animation ever
# 1393 Brilliant This is a must see film
# 2295 What a great drama
# 2600 It s a quite good movie
# 3061 harry potter go
# 3474 gimme the money baby
# 3655 This movie is I like
# 3779
# 3858 sihoo your best Come on
# 3998 a girl on the bridge with big eyes
# 4002 NO WAR DO PINK
# 4131
# 4708 Q Q o
# 영어로만 쓰여진 리뷰 수:20

# %%
test_ori = pd.read_csv('_data/test.csv', index_col=0)
train_ori = pd.read_csv('_data/train.csv', index_col=0)

# %%
for i in onlyEng:
    print(f'리뷰: {test_ori.document[i+1]}, 예측: {pred[i]}')
# Out:
# 리뷰: Childhood fantasy, 예측: 0
# 리뷰: "Amazing discovery!", 예측: 0
# 리뷰: LIFE + DOG = GREAT, 예측: 0
# 리뷰: It was very good!!!, 예측: 1
# 리뷰: You saw what you wanted to see., 예측: 0
# 리뷰: thank you! very good job ^^, 예측: 1
# 리뷰: It was a nice super duper!!!!, 예측: 1
# 리뷰: Best animation ever, 예측: 0
# 리뷰: Brilliant! This is a must-see film, 예측: 1
# 리뷰: What a great drama!!!, 예측: 1
# 리뷰: It's a quite good movie!, 예측: 1
# 리뷰: harry potter go!, 예측: 0
# 리뷰: gimme the money baby!, 예측: 0
# 리뷰: This movie is I like, 예측: 0
# 리뷰: ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ, 예측: 0
# 리뷰: sihoo,your best! Come on!, 예측: 0
# 리뷰: a girl on the bridge with big eyes, 예측: 1
# 리뷰: NO WAR ! DO PINK !!, 예측: 1
# 리뷰: ㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎㅎ, 예측: 0
# 리뷰: (￣∇￣)づQ(^.^Q)＼( ˚ ▽ ˚ ) /(/^o^)/, 예측: 1

# %%
reviews=[0,0]
for i, s in enumerate(train_ori.document):
    if '!' in s:
        l = '[긍정]' if train_ori.label[i+1]==1 else "[부정]"
        reviews[train_ori.label[i+1]]+=1
        print(l, s)
# Out:
# [긍정] 괜찮은 음악영화가 또 나왔군요!!! 따뜻한 겨울이 될 것 같아요~
# [긍정] 가슴 찡했던, 오래 기억에남을 영화!!
# [긍정] 즐겁게 본 성장 영화! 화이팅!
# [긍정] 멋진 상상력! 아름다운 영화. 여배우 소이의 재발견!
# [부정] 개빡치게하는드라마!!질퍽거려너 토나올지경이다!!
# [긍정] 닥터후 시리즈는 뭐다??? 관심이다!!
# [긍정] 눈물흘리면서 봤습니다. 그리스도인들에게 추천합니다!
# [긍정] 재밌게 잘 봤어요ㅋㅋㅋ 남자너무멋져!!
# [긍정] 재미있다고!!!!! 블루레이 짱짱 화려한 배경 짱짱
# [긍정] 안토니오 반데라스가 어떤 배우인지 보여준다!
# [긍정] 내가 좋아하는 배우다 여운이 긴 영화 감동감동!!
# [긍정] 이게 예술이야~!! 멋져~!! 모처럼 진짜 멋진 영화를 접했어~!
# [긍정] 너무 기분좋게봣습니다~ 적극 추천!!
# [부정] 소소에 지루한 이별여행...관심없다!
# [긍정] 이 영화는 8점대를 넘어야 정상인 영화다!
# [긍정] 진짜 드러나기 싫어하는 호프만의 모습이 인상적!
# [긍정] 시원하게 웃을 수 있게 해주는 드라마!ㅋ
# [부정] 아직도안끝났나?전파낭비다 차라리다큐를해라 피디도능력없음바꿔라!
# [긍정] 외로운 사람들 인연이 더욱 따뜻하게 다가왔던..!!
# [긍정] ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ좋네요!뭔가통쾌하고 유머러스하네요
# [부정] 시간이 아깝다. (10자 이상!)
# [부정] 영화 예고편이 제일 무서워요!
# [부정] 이게무슨짓이야!! 이게 이영화 평입니다.
# [부정] 진짜 돈 아까워!!열라 내가 해도 그거보다 잘한다-_-
# [부정] 정말 배우들이 아깝다...!!
# [부정] 그만 좀 우려먹어라!! 재미와 흥미 없으며 이젠 지겹다
# [긍정] 오래된 영화지만 이렇게 실감나다니....! 참으로 명작이로고...
# [긍정] 보리울의 여름 O.S.T.노래 정말 좋아요!!^.^
# [긍정] 와우!!! 10점준 이유를 알았어!!!! 대박...
# [긍정] 전 초딩인데도 재밌게 봤음..... ㅋㅋ 김선아 짱~!!!!!!!!
# [긍정] 전혀 지루할 틈이 없는 영화!
# [긍정] 신문지를 쓰고 날으는 4인은 아름다웠다!ㅋㅋㅋㅋ
# [긍정] 사투리 아줌마! 대박 ㅎㅎㅎ 재밌당 은나아~~
# [긍정] 저 덕심 쥐뿔도 없지만 정말 재미있었어요!

# %%
reviews
# Out:
# [115, 357]

# %%
reviews=[0,0]
for i, s in enumerate(train_ori.document):
    if '~' in s:
        l = '[긍정]' if train_ori.label[i+1]==1 else "[부정]"
        reviews[train_ori.label[i+1]]+=1
        print(l, s)
reviews
# Out:
# [긍정] 괜찮은 음악영화가 또 나왔군요!!! 따뜻한 겨울이 될 것 같아요~
# [부정] 이런 영화도 만들수가 있구나~
# [긍정] 기분전환에 좋은 영화였습니다.~
# [긍정] 이게 예술이야~!! 멋져~!! 모처럼 진짜 멋진 영화를 접했어~!
# [긍정] 너무 기분좋게봣습니다~ 적극 추천!!
# [긍정] 그냥 가슴이 뭉클하고 다시 중고등학교때 추억과 마치 그때느낌이 든다~
# [부정] 처음에는 나름 좋았는데 아쉽다...허나 배우들이 많이 나오네~ㅋ
# [긍정] 완전 재밌어요~~ 연기도 다들 잘하고 이쁘고 짱짱!!!대박나길♥?♥?♥?
# [긍정] 소소한 감동~ 보고 나서 더 생각나는 영화
# [긍정] 내가 본 일드 중 쵝오~!!!!!>0<
# [긍정] 절로 사람 힘 빠지는 곳 이야기 그래서 더 감동적~
# [긍정] 너무 재미있어요. 해피앤딩으로 끝났으면 좋겠어요~태희자은 행복하게 해주세요!
# [긍정] ㅋㅋㅋㅋㅋ은근히재미엇는데...ㅋㅋㅋㅋㅋㅋㅋㅋㅋ나두초딩때봣어~~~~~~~~~~
# [긍정] 진띰 완전 잘생겼어~!!>< 피터팬,,ㅎ
# [긍정] 정말 잘만든 드라마였습니다 . 좋은결말이었지만 너무일찍끝나 아쉽네요~
# [긍정] 정우성이라는 배우를 다시 보게된 영화. 허진호 감독의 영화는 다 좋다~
# [부정] 공포를 조금 즐기는 편이나 이건,, 도대체 ... 휴~~
# [긍정] 윤은혜..주지훈..너무조아~^^
# [긍정] 평점 왜이렇게낮나요? 너무사랑스러운 로맨스영화.. 재미있어요 ~~~
# [긍정] 잼있다.특이해.아니 별 1나준사람들 이해하기가 쉽지않아요~~~~
# [부정] 모냐..~~~어이없는 불륜 영화네
# [긍정] 따뜻한 영화~ 너무 좋았어요~~
# [부정] 견자단과 성룡의 대결씬과 이쁜 여자들만 볼만~ 나머진 기대 하지 말것
# [긍정] 한국판 러브스토리의 최고봉~!
# [긍정] 소재를 잘 살려서 재밋게 봄~ 나카시마 미카 짱
# [긍정] 최고... 내가 완전 좋아했었던 드라마 ... 또 보고싶당 굿~
# [긍정] 갈수록 빠져드네요^^주말이 기달려집니다~
# [부정] 롱~롱~롱~테이크!! 환장할 만큼 지루한 영화!!
# [부정] tv 전기세가 아깝다 캬악 퉷~
# [부정] 이게뭐야... 아니 그래서 어쩌라는겨~ 별 시덥잖은 내용이구만~
# [부정] 설정만 그럴듯하고, 개연성과 플롯은 나몰라라~.
# [부정] 가벼운 영화. 지젤 번천 연기 꽝~
# [긍정] 대형블럭버스터못지않은긴장과전율,감동영화,원츄~
# [부정] 메리에겐~을 기대하며 봤는데 영.......
# [긍정] 언니 오빠들~~저는 영원한 팬입니다.
# [부정] 그냥그래요 아이가좋아하네요~~~~
# [긍정] 쏴으뢍의 궈무붸엔드 뙀! 딱~이 궛물줄 봭빵슥이다
# [부정] 대실망 ㅡㅡ^ 연재 후반정도에 상당히 강해졌었는데~ 이건 뭐.....
# [긍정] 넘 재밌게 잘 봤어요금요일이 기다려질만큼요~~~
# [긍정] 1~2화보고 그냥 코미디인줄 알았는데 나름 감동도 있음! 꼭봐라 두번봐라 ㅋ
# [긍정] 승기승기 멋있어~~ㅎㅎ 역쉬 착한드라마~~~~♡ㅇ♡
# [부정] 스몰빌의 대스타 탐웰링때메 봤지만 정말쓰레기다~!!
# [긍정] 참 아름다운 영화~숨어있는 진주같은 영화..
# [긍정] 굳~~~~~~~~~~~~~~~~~~~~~~~
# [긍정] 최고의 레이싱 영화 이 때로 다시 돌아갔으면~
# [긍정] 평점왜이리낮지?난재밌게봤는데~
# [긍정] 대단하다. 대단해. 영화를 보고 난 후 올려다본 하늘에 별이 쫘르르르~
# [부정] 와~ 이런 것도 영화라고... 차라리 뮤직비디오를 만드는 게 나을 뻔
# [긍정] 이거 괜찮은데? 보고나니 기분이 매우 좋아졌다~~
# [긍정] 진짜 재밋음 시즌2만들어 주세요~
# [부정] 이건 공포가 아니고 코메디..ㅋㅋㅋ피식~
# [긍정] 차태현 여전하네 정말 ~ 만년 소년같으다
# [부정] 평점 잘 봐.. 이거 재미없어.. 전쟁신만 살짝 볼만해~
# [부정] 재개봉이라니 이건 말도 않됌 이건 사기임~!!!
# [긍정] 넘치는 윗트와 상상력! 그리고 그로밋 너무 귀여워요~ >ㅁ<
# [부정] B급 영화 무시하나효? 이건 C급입니다그려~. 어설프고 조악한 졸작
# [부정] 흐미...댓글 알바들 제바알~~
# [긍정] 전 초딩인데도 재밌게 봤음..... ㅋㅋ 김선아 짱~!!!!!!!!
# [부정] 답답~하게 전개되는/70년대 영환줄 알았다/그렇게 우울하게 허무하게 끝나냐?
# [긍정] 벌과 인간과의 환상적인 세계~
# [긍정] 요즘 진짜 재밌게 보는 드라마~ 꿀잼많은 사람들이 나처럼 보고 즐기길~^^
# [긍정] 사투리 아줌마! 대박 ㅎㅎㅎ 재밌당 은나아~~
# [긍정] 아~~오랜 기다림끝에 드디어 보게 되네요 최고입니다
# [96, 206]

# %%
reviews=[0,0]
for i, s in enumerate(train_ori.document):
    if ';' in s:
        l = '[긍정]' if train_ori.label[i+1]==1 else "[부정]"
        reviews[train_ori.label[i+1]]+=1
        print(l, s)
reviews
# Out:
# [부정] 섹시하지도 귀엽지도 않은데 뭘 어쩌라는건지..ㅡㅡ;;
# [부정] 조잡한 화면에..우선. 졸작...;;
# [부정] 진심 연예인 성우 좀 쓰지마라;; 저게 뭐냐 저게;;;
# [부정] 어쩌다 이걸보게되선 ㅡㅡ;; 시간이 진짜 아깝다
# [긍정] 모르겠네요. 쟁쟁한 다른 작품들이 있어서 묻힐것 같습니다;;
# [긍정] 평점이 너무 낮네; ㅋㅋㅋ쨋든 잼잇엇음 ㅋㅋㅋ
# [부정] 우웩;; 이해하려고 노력해도 못하겟음;;
# [부정] 영화라기보다는 그냥 투어 촬영 편집본이죠;;; 졸렸습니다.
# [긍정] 조연들의 인간다운 연기가 돋보였던 영화 ^^;
# [부정] 유치 뽕짝;; OO.. 예전 향수 떠올리는 선플때문에 보다가 토나올뻔했음;;
# [부정] -,-;;;; 무간도 아류작인가? 보다 말았음.
# [긍정] 1992년도 스릴러가 이정도의 완성도를 자랑하다니;; 수작
# [부정] 최악.............;; 정말 별로 중에 별로
# [긍정] 액션 정말 잘만들었더라. 사토상 멋있다;ㅋㅋㅋㅋ 즐기기에 충분한 영화
# [부정] 이러면안되는거아닌가;; 내 두시간 돌려주세요!!
# [부정] 밑에 평가하신 분들 다 스텝들인가요;;
# [부정] ..글쎄다...쇼킹하긴하지만 노골적으로 할필요까진..;; 엽기적이다.
# [부정] 무슨 이런 영화가.. -_-;; 내가 이해력이 부족한 건가??
# [부정] 원작의 묘미는 어디가고 각색 연출 너무 허접해;;
# [긍정] 열린입이라고 남드라마헐뜯고하는거아니야^^;이해못하는걸 왜남탓을하지?이해안되네
# [부정] 첨엔 좀 볼만한가 했더니;; 시간 아깝네
# [부정] 카지노로얄 만든 감독이 만들었는데, 왜 이 모양? ㅡㅡ;
# [부정] 어제 케이블에서 하는거 봤는데 다 짤라서 엉망이었던 -_-;
# [부정] 나는 관대하다..그것도 아주 ㅡㅡ;;
# [부정] 아니왜 코미디영화를 재미없게만들지;;;
# [부정] 개후진영화 ㅡㅡ.. 2시간30분동안 지루해죽는줄 ㅡㅡ;;
# [부정] 켄신 빠돌이로서 한마디 돈아깝다 -_-;; 제관점은 추억편 영향이 큰듯.
# [부정] 맞아요! 지루해요.. 전 전형적인 한국인의 정서라서,,^^;;;
# [부정] 신세경때문에 다시 찾아봄..그래도 후하진 못해..뭐니 이게;
# [부정] 상어라고 해놓고 상어가 안나오네; 낚시질 영화..^^
# [부정] 1편 굿..2편 볼만함..3편 지루 ㅡㅡ;;
# [긍정] 오늘 한다 두번더 보내 ㅡㅡ;
# [긍정] 감동이다 ㅠㅠ 84년도 작품이라니 대박;
# [부정] ㅡㅡ;;;근데 시사회가서 머하는것인지.....
# [부정] 호기심에 1회보다가 진짜 눈썩는줄알았다 -- 졸1라 재미없어;
# [부정] 뭐냐 주인공을 꽃미녀로 둔갑??개념이 없어;;;
# [긍정] 가볍고 재밌게 볼 수 있는 영화. 여주가 너무이뻤다;;
# [부정] 뭐 이딴 기승전결이 다있어;;뭐야 이 말도 안되는 평점은??;;
# [부정] 걍 그럼..솔직히 뭐 1이나 2나 너무 재미가 없네 ;;
# [부정] 꼴깝 떨고 앉았있네 ㅡㅡ;; 별 시덥잖은 의미;;
# [부정] 당황스럽네여;; 1화를 안봐서 그런건지는 모르겠지만.. 정말 당황스러워요;;
# [부정] 내가 본 최악의 영화였다..ㅡ.ㅡ;;
# [부정] 영화관에서 봤엇는데 지루해서 잣던 기억이 ㅡㅡ;;;;;;;;;성룡영화중 최악
# [부정] 의도는좋았으나.전달이영아닌데-_-;;;
# [부정] 해피투게더 역사상 이렇게 답답해보이는 앵글은 첨이네ㅡㅡ;
# [긍정] 킴 노박 진짜 예쁜데;;; 왜 그레이스 켈리만 계속 섭외쇄도 했었나...
# [부정] 도대체 프랑스는 요새 스릴러 왜이러니..;;
# [부정] ,,,,,,,처음과 끝이 너무 다르다,,,무슨말을 하고 싶은건지- -;
# [부정] 난왜별로지;; 다 팬심으로보는건가? 연기도어색하고 집중도안되던데 노잼
# [부정] 더봐야 알겠지만.. 이즈미 노아가 단발로 나온것 부터가 에러 ㅡㅡ;
# [부정] 다알바생임? 나 완전 잼없게 봤는데;ㅋㅋ
# [부정] 시간이 남아돌면 추천 ㄷㄷ;;
# [긍정] 헐 재밌는데 왜 평점이 이래;
# [부정] 웃기지도 않코 액션도 없고.. 몰보라는겨..;;
# [긍정] 케이샤양 연기 너무 잘해요~ 관심 많이 가져주시길^^;
# [긍정] 힘들었던. ;;그시대가 그립다
# [부정] 잔인함의 묘사가; 에일리언1~2에서 나오는 정도로정말정말실망했어요;
# [부정] 배우맞음??연기가왜그따구여;;연기하는거티나너무오버해서;;
# [부정] 질질끄네....;;돈없는거로 궁상떠는걸로 4주쓰냐
# [부정] 실망스런 스토리에, 허약하기 그지없는 늑대변신모드란...ㅡㅡ;
# [부정] 이 감독넘은 전작부터해서 정신상태가 의심스러운넘일세..ㅡㅡ;;
# [부정] 이렇게 찍으면 뭔가 좀 있어보이냐? ;;;
# [긍정] 재미있게 봤지만 몬가 아쉬웠던 ;;
# [부정] 0점; 엉망인 캐릭터에만 맞기지 말고 제작진께서도 개념을 갖추셔야 할듯;;
# [부정] 분명 잼있을거 같은 소잰데 산만하고 집중이 안됨; 연출이 아쉬운 영화.
# [부정] 너무기대를 많이해서 그런지 썩 재미있지는않다; 내용이 너무가벼워서
# [부정] 전작에서 써먹은 반전을 또써먹네;
# [부정] 평점이 10점이라 평균 마출려구 왔슴;;;
# [부정] 2002년 작인 걸 감안해도 0점도 아깝다;;;;
# [부정] 투자자들 개부자; 이런 영화에 투자하다니
# [부정] ㅋㅋㅋㅋ 웃음밖엔 ;; -_-
# [부정] 박보영만 봣는데 별로네 ;... 별루임..내 스타일이아니얌..
# [부정] 남자 잘못만나서 인생 망치는 영화... 대략 난감;;
# [부정] 어쩌자고 이런 영화를..;; 킬링타임도 안된다. =ㅛ=ㅋ
# [부정] 장진감독의 영화 아는여자 표절도 아니고 완전 뭐야 이게;;
# [부정] 아나,, 실화고 나발이고 머 이런 ㅡㅡ;
# [긍정] 영상미가 진짜 최고; 시리즈로계속나와야함..이건..ㄷㄷㄷ
# [부정] 이게영화냐; 오늘난 쓰레기 두편을 보았다 그중한편
# [부정] 뭘 어쩌시려고 이렇게 꼬는지 참;;;
# [부정] 아...지겹다...너무 흥한 고어물...허접하고...전개도 엉성하고;;;
# [부정] 이 영화가 2011년도 영화라는 게 믿을 수 없다 ㅡㅡ;
# [부정] 하아 -_-;; 완전 재미없네.. 이건 뭐-_-
# [부정] 별로 인거 같음; 시간이 아까움ㅠㅠ 기억에도 안남을거 같고!
# [부정] 평점 2점대인 드라마는 처음본다;; 얼마나 재미없길래;;
# [부정] 드래곤볼 액션은 슈퍼맨 빼긴거야;
# [부정] 심각한상황에 고기구워먹고 술먹고 영화 미친듯;
# [부정] 에휴;; 같은 한국인으로써 부끄럽다
# [부정] 진짜 지금까지 본 영화 중에 제일 쓰레기;;
# [부정] 감독이 일본인이었군 어쩐지 칼과 도끼만 주구장창;;
# [부정] 끔찍하네요 이영화...끔찍하게 재미없음;;
# [부정] 내인생최악의영화-_- 영화보다 도중에 나가고 싶은건 처음이었음..ㅡㅡ;
# [부정] 전개가 진짜;; ㅋㅋㅋ 할말이없다
# [부정] 왜 이렇게 평점높지...난 보다가 잤는데...;;
# [부정] -_-..진짜지루하다 시간낭비 ;; 내시간돌려줭
# [부정] 이걸 왜 만들었을까요? ㅡㅡ;;;
# [부정] 이영화보고 영화결핍증 걸렸다ㅡㅡ;;
# [부정] 재미없는데 평점이 왜이렇게 높죠?;;
# [부정] 아~~~~무 내용없는 영화..ㅡㅡ;
# [부정] 4년전에 이거왜봤는지 모르겠네 공룡이라서 4점;
# [부정] 요것도 미이라시리즈와같이 연기력이좀 떨어진다;; 7점짜리영화
# [부정] 최악이였다..기대가 커서 그랬나;
# [부정] 이 영화 개봉뒤로 감독 현재 실종상태;;
# [부정] 뭐가 코미디란건지;; 그냥 가볍게 연출한게 코미디라고?이해가안가네.끝이 허무
# [부정] 0.5점도 아깝다 이딴 쓰레기 왜 만드는거야? 감독 수준이 참 ㅡㅡ;
# [긍정] 이것때문에 잘하면 십타쿠 될뻔.. ;; 에휴.. 빠져나올수없는 네티.. !!
# [부정] 그냥 공포영화의 답답한 법칙을 그대로 적용시킨 이색 공포영화임^^;;
# [긍정] 평점이 왜이리 낮을까요?;; 이거 재미있습니다 ㅇㅇ
# [부정] 평점이 너무 높아서 웃긴 이 기분 ^^;;
# [긍정] 황정음 나오는드라마는 당연히 10점줘야지;
# [부정] 세남자의 인생이 기억때문에 다 틀어진건아니지;-- 그저 데이브만 불쌍할뿐..
# [긍정] 보고 싶어도 내가 사는 지방에는 개봉조차 안하네..ㅡㅡ;;
# [부정] 요리를 해야지 어째 다큐를;;
# [긍정] 2년만에 수목드라마를 다시 보다;
# [부정] 손발이 오글오글 한대 쳐주고 싶네;;;
# [부정] 전작은괜찮았는데..2는어찌..;;
# [부정] 아 놔;; 망작이라고밖에...
# [부정] 반개도 아까운 발연기 돌들 ;; 이현우가 그나마 낳앗네 ;
# [부정] 트레일러보고 결말이 너무 궁금해서 봤는데, 낭패...;;
# [98, 20]

# %% [markdown]
# * !, ~, ; 과 같은 특수문자는 긍/부정을 판단하는데 도움이 될 것이라고 추정
