# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score

# %%
train = pd.read_csv('./_data/train.csv', index_col=0)#id를 인덱스로
test = pd.read_csv('./_data/test.csv', index_col=0)

# %%
from pycaret.classification import *

# %% [markdown]
# * null이 포함되어있는 feature를 nan으로

# %%
# thal = 0 = Null 
train[train['thal']==0]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# id
# 130   53    0   2       128   216    0        0      115      0      0.0
#
#      slope  ca  thal  target
# id
# 130      2   0     0       1

# %%
test[test['thal']==0]
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# id
# 47   52    1   0       128   204    1        1      156      1      1.0
#
#     slope  ca  thal
# id
# 47      1   0     0

# %%
train.loc[train['thal']==0,'thal'] = np.nan
test.loc[test['thal']==0,'thal'] = np.nan
train.loc[train.thal==1, 'thal'] =np.nan
test.loc[test.thal==1, 'thal'] =np.nan

# %%
# ca = 4 = Null
train[train['ca']==4]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
test[test['ca']==4]
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# id
# 41   52    1   2       138   223    0        1      169      0      0.0
# 46   43    1   0       132   247    1        0      143      1      0.1
# 80   58    1   1       125   220    0        1      144      0      0.4
# 81   38    1   2       138   175    0        1      173      0      0.0
# 96   38    1   2       138   175    0        1      173      0      0.0
#
#     slope  ca  thal
# id
# 41      2   4     2
# 46      1   4     3
# 80      1   4     3
# 81      2   4     2
# 96      2   4     2

# %%
ca_y = test[test['ca']==4]

# %%
train_ca = train

y_train_ca = train_ca.pop('ca')
train_ca.pop('target')
x_train_ca = train_ca
x_train_ca
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# id
# 1     53    1   2       130   197    1        0      152      0      1.2
# 2     52    1   3       152   298    1        1      178      0      1.2
# 3     54    1   1       192   283    0        0      195      0      0.0
# 4     45    0   0       138   236    0        0      152      1      0.2
# 5     35    1   1       122   192    0        1      174      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 147   50    1   2       140   233    0        1      163      0      0.6
# 148   51    1   2        94   227    0        1      154      1      0.0
# 149   69    1   3       160   234    1        0      131      0      0.1
# 150   46    1   0       120   249    0        0      144      0      0.8
# 151   63    0   1       140   195    0        1      179      0      0.0
#
#      slope  thal
# id
# 1        0     2
# 2        1     3
# 3        2     3
# 4        1     2
# 5        2     2
# ..     ...   ...
# 147      1     3
# 148      2     3
# 149      1     2
# 150      2     3
# 151      2     2
#
# [151 rows x 12 columns]

# %%
ca_y
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# id
# 41   52    1   2       138   223    0        1      169      0      0.0
# 46   43    1   0       132   247    1        0      143      1      0.1
# 80   58    1   1       125   220    0        1      144      0      0.4
# 81   38    1   2       138   175    0        1      173      0      0.0
# 96   38    1   2       138   175    0        1      173      0      0.0
#
#     slope  ca  thal
# id
# 41      2   4     2
# 46      1   4     3
# 80      1   4     3
# 81      2   4     2
# 96      2   4     2

# %%
y_test_ca = test
y_test_ca = y_test_ca.drop([41,46,80,81,96])

# %%
y_train_ca_all = pd.concat([y_train_ca, y_test_ca.pop('ca')])
y_train_ca_all
# Out:
# id
# 1      0
# 2      0
# 3      1
# 4      0
# 5      0
#       ..
# 148    2
# 149    0
# 150    2
# 151    1
# 152    0
# Name: ca, Length: 298, dtype: int64

# %%
x_train_ca_all = pd.concat([x_train_ca, y_test_ca])
x_train_ca_all
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# id
# 1     53    1   2       130   197    1        0      152      0      1.2
# 2     52    1   3       152   298    1        1      178      0      1.2
# 3     54    1   1       192   283    0        0      195      0      0.0
# 4     45    0   0       138   236    0        0      152      1      0.2
# 5     35    1   1       122   192    0        1      174      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 148   64    0   0       130   303    0        1      122      0      2.0
# 149   43    0   0       132   341    1        0      136      1      3.0
# 150   53    1   0       123   282    0        1       95      1      2.0
# 151   67    0   2       152   277    0        1      172      0      0.0
# 152   43    0   2       122   213    0        1      165      0      0.2
#
#      slope  thal
# id
# 1        0     2
# 2        1     3
# 3        2     3
# 4        1     2
# 5        2     2
# ..     ...   ...
# 148      1     2
# 149      1     3
# 150      1     3
# 151      2     2
# 152      1     2
#
# [298 rows x 12 columns]

# %%
x_train_ca = pd.concat([x_train_ca, x_test_ca])

# %%
thal_y1 =  train[train['thal']==0]
thal_y2 =  test[test['thal']==0]

train.loc[train['thal']==0,'thal'] = np.nan
test.loc[test['thal']==0,'thal'] = np.nan

tr_train_thal = train.dropna()
tr_y_train_thal = tr_train_thal.pop('thal')
tr_x_train_thal = tr_train_thal
tr_x_train_thal
# train.loc[train.thal==1, 'thal'] =np.nan
# test.loc[test.thal==1, 'thal'] =np.nan

# %%
categorical_features =['sex', 'cp', 'exang', 'slope', 'ca', 'thal', 'restecg']

# %%
for i in categorical_features:
    print(train[i].value_counts())
# Out:
# 1    103
# 0     48
# Name: sex, dtype: int64
# 0    65
# 2    47
# 1    25
# 3    14
# Name: cp, dtype: int64
# 0    102
# 1     49
# Name: exang, dtype: int64
# 2    70
# 1    68
# 0    13
# Name: slope, dtype: int64
# 0    95
# 1    31
# 2    15
# 3    10
# Name: ca, dtype: int64
# 2.0    84
# 3.0    58
# Name: thal, dtype: int64
# 1    75
# 0    75
# 2     1
# Name: restecg, dtype: int64

# %%
for i in categorical_features:
    print(test[i].value_counts())
# Out:
# 1    104
# 0     48
# Name: sex, dtype: int64
# 0    78
# 2    40
# 1    25
# 3     9
# Name: cp, dtype: int64
# 0    102
# 1     50
# Name: exang, dtype: int64
# 2    72
# 1    72
# 0     8
# Name: slope, dtype: int64
# 0.0    80
# 1.0    34
# 2.0    23
# 3.0    10
# Name: ca, dtype: int64
# 2.0    82
# 3.0    59
# Name: thal, dtype: int64
# 1    77
# 0    72
# 2     3
# Name: restecg, dtype: int64

# %%
for i in categorical_features:
    print(f'train[{i}] : {train[i].isna().sum()}')
    print(f'test[{i}] : {test[i].isna().sum()}')
# Out:
# train[sex] : 0
# test[sex] : 0
# train[cp] : 0
# test[cp] : 0
# train[exang] : 0
# test[exang] : 0
# train[slope] : 0
# test[slope] : 0
# train[ca] : 0
# test[ca] : 5
# train[thal] : 9
# test[thal] : 11
# train[restecg] : 0
# test[restecg] : 0

# %%
train

# %%
x_train = train.dropna()

# %% [markdown]
# # 모델 만들기

# %% [markdown]
# #### 사용할 데이터
# * categorical_features : sex, cp, (exang), slope, ca, thal, restecg
# * numeric_features : age, (trestbps), (thalach), (fbs), (oldpeak), (chol)

# %%
SEED = 32

# %%
ignore_features = []
categorical_features = ['sex', 'cp', 'slope','exang', 'restecg', 'thal']
numeric_features = ['age', 'trestbps', 'thalach', 'fbs','oldpeak', 'chol']

# %%
# ignore_features = ['fbs','oldpeak', 'chol']
# categorical_features = ['sex', 'cp', 'slope', 'ca', 'thal','exang','restecg']
# numeric_features = ['age','trestbps', 'thalach']

# %%
ca_train = pd.concat([x_train_ca_all,y_train_ca_all], axis=1)
ca_train
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# id
# 1     53    1   2       130   197    1        0      152      0      1.2
# 2     52    1   3       152   298    1        1      178      0      1.2
# 3     54    1   1       192   283    0        0      195      0      0.0
# 4     45    0   0       138   236    0        0      152      1      0.2
# 5     35    1   1       122   192    0        1      174      0      0.0
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 148   64    0   0       130   303    0        1      122      0      2.0
# 149   43    0   0       132   341    1        0      136      1      3.0
# 150   53    1   0       123   282    0        1       95      1      2.0
# 151   67    0   2       152   277    0        1      172      0      0.0
# 152   43    0   2       122   213    0        1      165      0      0.2
#
#      slope  thal  ca
# id
# 1        0     2   0
# 2        1     3   0
# 3        2     3   1
# 4        1     2   0
# 5        2     2   0
# ..     ...   ...  ..
# 148      1     2   2
# 149      1     3   0
# 150      1     3   2
# 151      2     2   1
# 152      1     2   0
#
# [298 rows x 13 columns]

# %%
clf = setup(data=ca_train, 
            target='ca', 
            ignore_features=ignore_features,           
            categorical_features=categorical_features, 
            numeric_features=numeric_features,
            remove_outliers=True,
            #outliers_threshold=0.1,
            normalize=True,        
            normalize_method='zscore',    #minmax, zscore, maxabs, robust
            feature_selection=True,
            imputation_type='iterative',
          #  categorical_imputation='mode',
            iterative_imputation_iters=10,            
            categorical_iterative_imputer='lightgbm',
            trigonometry_features=True,
            session_id=SEED, 
            silent=True
            #profile=True
            )
# Out:
# <style  type="text/css" >
# #T_6df51312_63a5_11ec_9626_d050998ee3c7row29_col1,#T_6df51312_63a5_11ec_9626_d050998ee3c7row40_col1,#T_6df51312_63a5_11ec_9626_d050998ee3c7row44_col1,#T_6df51312_63a5_11ec_9626_d050998ee3c7row49_col1,#T_6df51312_63a5_11ec_9626_d050998ee3c7row52_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_6df51312_63a5_11ec_9626_d050998ee3c7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row0_col1" class="data row0 col1" >32</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row1_col1" class="data row1 col1" >ca</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row2_col1" class="data row2 col1" >Multiclass</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row3_col1" class="data row3 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row4_col1" class="data row4 col1" >(298, 13)</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row5_col1" class="data row5 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row6_col1" class="data row6 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row7_col1" class="data row7 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row11_col1" class="data row11 col1" >(190, 15)</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row12_col1" class="data row12 col1" >(90, 15)</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_6df51312_63a5_11ec_9626_d050998ee3c7row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_6df51312_63a5_11ec_9626_d050998ee3c7level0_row18" class="row_heading level0 row18" >18</th>

# %%
best_models = compare_models(sort='Accuracy', n_select=3, fold=5)
# Out:
# <style  type="text/css" >
#     #T_7914ec50_63a5_11ec_aa20_d050998ee3c7 th {
#           text-align: left;
#     }#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row0_col0,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row0_col2,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row0_col3,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row0_col4,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row0_col5,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row0_col6,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row0_col7,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row1_col0,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row1_col2,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row1_col3,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row1_col4,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row1_col5,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row1_col6,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row1_col7,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row2_col0,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row2_col1,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row2_col2,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row2_col3,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row2_col4,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row2_col5,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row2_col6,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row2_col7,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row3_col0,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row3_col1,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row3_col2,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row3_col3,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row3_col4,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row3_col5,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row3_col6,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row3_col7,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row4_col0,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row4_col1,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row4_col3,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row4_col7,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row5_col0,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row5_col1,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row5_col2,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row5_col3,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row5_col4,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row5_col5,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row5_col6,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row5_col7,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row6_col0,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row6_col1,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row6_col2,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row6_col3,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row6_col4,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row6_col5,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row6_col6,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row6_col7,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row7_col0,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row7_col1,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row7_col2,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row7_col3,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row7_col4,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row7_col5,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row7_col6,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row7_col7,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row8_col0,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row8_col1,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row8_col2,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row8_col4,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row8_col5,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row8_col6,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row9_col0,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row9_col1,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row9_col2,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row9_col3,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row9_col4,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row9_col5,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row9_col6,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row9_col7,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row10_col0,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row10_col1,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row10_col2,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row10_col3,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row10_col4,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row10_col5,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row10_col6,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row10_col7,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row11_col0,#T_7914ec50_63a5_ ...
#             text-align:  left;
#             text-align:  left;
#         }#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row0_col1,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row1_col1,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row4_col2,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row4_col4,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row4_col5,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row4_col6,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row8_col3,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row8_col7{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#         }#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row0_col8,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row3_col8,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row6_col8,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row13_col8,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row14_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  yellow;
#             background-color:  lightgrey;
#         }#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row1_col8,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row2_col8,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row4_col8,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row5_col8,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row7_col8,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row8_col8,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row9_col8,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row10_col8,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row11_col8,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row12_col8,#T_7914ec50_63a5_11ec_aa20_d050998ee3c7row15_col8{
#             text-align:  left;
#             text-align:  left;
#             background-color:  lightgrey;
#         }</style><table id="T_7914ec50_63a5_11ec_aa20_d050998ee3c7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Model</th>        <th class="col_heading level0 col1" >Accuracy</th>        <th class="col_heading level0 col2" >AUC</th>        <th class="col_heading level0 col3" >Recall<

# %%
tuned_top3 = [tune_model(i) for i in best_models]
blender = blend_models(tuned_top3)
stacker = stack_models(tuned_top3)
best_auc_model = automl(optimize = 'Accuracy')
finalized_model = finalize_model(best_auc_model)
# Out:
# <style  type="text/css" >
# #T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row10_col0,#T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row10_col1,#T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row10_col2,#T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row10_col3,#T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row10_col4,#T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row10_col5,#T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row10_col6{
#             background:  yellow;
#         }</style><table id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row0_col0" class="data row0 col0" >0.7273</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row0_col1" class="data row0 col1" >0.0000</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row0_col2" class="data row0 col2" >0.5000</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row0_col3" class="data row0 col3" >0.6273</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row0_col4" class="data row0 col4" >0.6453</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row0_col5" class="data row0 col5" >0.3265</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row0_col6" class="data row0 col6" >0.4472</td>
#             </tr>
#             <tr>
#                         <th id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row1_col0" class="data row1 col0" >0.7273</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row1_col1" class="data row1 col1" >0.0000</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row1_col2" class="data row1 col2" >0.5000</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row1_col3" class="data row1 col3" >0.6273</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row1_col4" class="data row1 col4" >0.6453</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row1_col5" class="data row1 col5" >0.3265</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row1_col6" class="data row1 col6" >0.4472</td>
#             </tr>
#             <tr>
#                         <th id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row2_col0" class="data row2 col0" >0.6364</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row2_col1" class="data row2 col1" >0.8207</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row2_col2" class="data row2 col2" >0.3393</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row2_col3" class="data row2 col3" >0.6591</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row2_col4" class="data row2 col4" >0.6303</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row2_col5" class="data row2 col5" >0.2787</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row2_col6" class="data row2 col6" >0.2902</td>
#             </tr>
#             <tr>
#                         <th id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row3_col0" class="data row3 col0" >0.7273</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row3_col1" class="data row3 col1" >0.6409</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row3_col2" class="data row3 col2" >0.5000</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row3_col3" class="data row3 col3" >0.5404</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row3_col4" class="data row3 col4" >0.6174</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row3_col5" class="data row3 col5" >0.4107</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row3_col6" class="data row3 col6" >0.4719</td>
#             </tr>
#             <tr>
#                         <th id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row4_col0" class="data row4 col0" >0.5455</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row4_col1" class="data row4 col1" >0.8152</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row4_col2" class="data row4 col2" >0.5179</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row4_col3" class="data row4 col3" >0.6000</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row4_col4" class="data row4 col4" >0.5455</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row4_col5" class="data row4 col5" >0.2763</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row4_col6" class="data row4 col6" >0.2965</td>
#             </tr>
#             <tr>
#                         <th id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row5_col0" class="data row5 col0" >0.7000</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row5_col1" class="data row5 col1" >0.0000</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row5_col2" class="data row5 col2" >0.7381</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row5_col3" class="data row5 col3" >0.7333</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row5_col4" class="data row5 col4" >0.7051</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row5_col5" class="data row5 col5" >0.4231</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row5_col6" class="data row5 col6" >0.4335</td>
#             </tr>
#             <tr>
#                         <th id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row6_col0" class="data row6 col0" >0.5000</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row6_col1" class="data row6 col1" >0.0000</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row6_col2" class="data row6 col2" >0.2381</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row6_col3" class="data row6 col3" >0.4375</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row6_col4" class="data row6 col4" >0.4667</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row6_col5" class="data row6 col5" >-0.1905</td>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row6_col6" class="data row6 col6" >-0.2085</td>
#             </tr>
#             <tr>
#                         <th id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e80a0230_63a3_11ec_bd3d_d050998ee3c7row7_

# %%
predictions = predict_model(data=ca_y, estimator=finalized_model)
predictions
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-246-3fb70c3cd955> in <module>
# ----> 1 predictions = predict_model(data=ca_y, estimator=finalized_model)
#       2 predictions
#
# ~\.conda\envs\py36-jupyter\lib\site-packages\pycaret\classification.py in predict_model(estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose)
#    2011         round=round,
#    2012         verbose=verbose,
# -> 2013         ml_usecase=MLUsecase.CLASSIFICATION,
#    2014     )
#    2015
#
# ~\.conda\envs\py36-jupyter\lib\site-packages\pycaret\internal\tabular.py in predict_model(estimator, data, probability_threshold, encoded_labels, raw_score, round, verbose, ml_usecase, display)
#    8747         estimator = get_estimator_from_meta_estimator(estimator)
#    8748
# -> 8749     pred = np.nan_to_num(estimator.predict(X_test_))
#    8750
#    8751     try:
#
# ~\.conda\envs\py36-jupyter\lib\site-packages\sklearn\utils\metaestimators.py in <lambda>(*args, **kwargs)
#     117
#     118         # lambda, but not partial, allows help() to work with update_wrapper
# --> 119         out = lambda *args, **kwargs: self.fn(obj, *args, **kwargs)
#     120         # update the docstring of the returned function
#     121         update_wrapper(out, self.fn)
#
# ~\.conda\envs\py36-jupyter\lib\site-packages\sklearn\pipeline.py in predict(self, X, **predict_params)
#     406         for _, name, transform in self._iter(with_final=False):
#     407             Xt = transform.transform(Xt)
# --> 408         return self.steps[-1][-1].predict(Xt, **predict_params)
#     409
#     410     @if_delegate_has_method(delegate='_final_estimator')
#
# ~\.conda\envs\py36-jupyter\lib\site-packages\sklearn\ensemble\_forest.py in predict(self, X)
#     627             The predicted classes.
#     628         """
# --> 629         proba = self.predict_proba(X)
#     630
#     631         if self.n_outputs_ == 1:
#
# ~\.conda\envs\py36-jupyter\lib\site-packages\sklearn\ensemble\_forest.py in predict_proba(self, X)
#     671         check_is_fitted(self)
#     672         # Check data
# --> 673         X = self._validate_X_predict(X)
#     674
#     675         # Assign chunk of trees to jobs
#
# ~\.conda\envs\py36-jupyter\lib\site-packages\sklearn\ensemble\_forest.py in _validate_X_predict(self, X)
#     419         check_is_fitted(self)
#     420
# --> 421         return self.estimators_[0]._validate_X_predict(X, check_input=True)
#     422
#     423     @property
#
# ~\.conda\envs\py36-jupyter\lib\site-packages\sklearn\tree\_classes.py in _validate_X_predict(self, X, check_input)
#     397                              "match the input. Model n_features is %s and "
#     398                              "input n_features is %s "
# --> 399                              % (self.n_features_, n_features))
#     400
#     401         return X
#
# ValueError: Number of features of the model must match the input. Model n_features is 21 and input n_features is 15

# %%
submission['target'] = predictions['Label']
submission

# %%
submission.to_csv('./submission9.csv')

# %%
clf = setup(data=train, 
            target='target', 
            ignore_features=ignore_features,           
            categorical_features=categorical_features, 
            numeric_features=numeric_features,
            remove_outliers=True,
            #outliers_threshold=0.1,
            normalize=True,        
            normalize_method='zscore',    #minmax, zscore, maxabs, robust
            feature_selection=True,
            #feature_selection_threshold=0.9,
            imputation_type='iterative',
            categorical_imputation='mode',
            iterative_imputation_iters=10,            
            categorical_iterative_imputer='xgboost',
            trigonometry_features=True,
            session_id=SEED, 
            silent=True
            #profile=True
            )
