# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import warnings
warnings.filterwarnings('ignore')

from sklearn.model_selection import cross_val_score
from sklearn.metrics import f1_score

# %%
train = pd.read_csv('./_data/train.csv', index_col=0)#id를 인덱스로
test = pd.read_csv('./_data/test.csv', index_col=0)

# %%
from pycaret.classification import *

# %% [markdown]
# * null이 포함되어있는 feature를 nan으로

# %%
# thal = 0 = Null 
train[train['thal']==0]
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# id
# 130   53    0   2       128   216    0        0      115      0      0.0
#
#      slope  ca  thal  target
# id
# 130      2   0     0       1

# %%
test[test['thal']==0]
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# id
# 47   52    1   0       128   204    1        1      156      1      1.0
#
#     slope  ca  thal
# id
# 47      1   0     0

# %%
train.loc[train['thal']==0,'thal'] = np.nan
test.loc[test['thal']==0,'thal'] = np.nan

# %%
# ca = 4 = Null
train[train['ca']==4]
# Out:
# Empty DataFrame
# Columns: [age, sex, cp, trestbps, chol, fbs, restecg, thalach, exang, oldpeak, slope, ca, thal, target]
# Index: []

# %%
test[test['ca']==4]
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# id
# 41   52    1   2       138   223    0        1      169      0      0.0
# 46   43    1   0       132   247    1        0      143      1      0.1
# 80   58    1   1       125   220    0        1      144      0      0.4
# 81   38    1   2       138   175    0        1      173      0      0.0
# 96   38    1   2       138   175    0        1      173      0      0.0
#
#     slope  ca  thal
# id
# 41      2   4   2.0
# 46      1   4   3.0
# 80      1   4   3.0
# 81      2   4   2.0
# 96      2   4   2.0

# %%
test.loc[test['ca']==4,'ca'] = np.nan

# %%
print(train['thal'].isna().sum())
print(test['thal'].isna().sum())
# Out:
# 1
# 1

# %%
print(train['ca'].isna().sum())
print(test['ca'].isna().sum())
# Out:
# 0
# 5

# %% [markdown]
# # 모델 만들기

# %% [markdown]
# #### 사용할 데이터
# * categorical_features : sex, cp, (exang), slope, ca, thal, restecg
# * numeric_features : age, (trestbps), (thalach), (fbs), (oldpeak), (chol)

# %%
SEED = 32

# %%
# ignore_features = []
# categorical_features = ['sex', 'cp', 'slope', 'ca','exang', 'restecg', 'thal']
# numeric_features = ['age', 'trestbps', 'thalach', 'fbs','oldpeak', 'chol']

# %%
ignore_features = ['fbs','oldpeak', 'chol', 'restecg','trestbps', 'thalach']
categorical_features = ['sex', 'cp', 'slope', 'ca', 'thal','exang']
numeric_features = ['age']

# %%
clf = setup(data=train, 
            target='target', 
            ignore_features=ignore_features,           
            categorical_features=categorical_features, 
            numeric_features=numeric_features,
            remove_outliers=True,
            #outliers_threshold=0.1,
            normalize=True,        
            normalize_method='zscore',    #minmax, zscore, maxabs, robust
            feature_selection=True,
            #feature_selection_threshold=0.9,
            imputation_type='iterative',
            categorical_imputation='mode',
            iterative_imputation_iters=10,            
            categorical_iterative_imputer='xgboost',
            trigonometry_features=True,
            session_id=SEED, 
            silent=True
            #profile=True
            )
# Out:
# <style  type="text/css" >
# #T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row5_col1,#T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row29_col1,#T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row40_col1,#T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row44_col1,#T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row49_col1,#T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row52_col1{
#             background-color:  lightgreen;
#         }</style><table id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Description</th>        <th class="col_heading level0 col1" >Value</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row0_col0" class="data row0 col0" >session_id</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row0_col1" class="data row0 col1" >32</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row1_col0" class="data row1 col0" >Target</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row1_col1" class="data row1 col1" >target</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row2_col0" class="data row2 col0" >Target Type</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row2_col1" class="data row2 col1" >Binary</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row3_col0" class="data row3 col0" >Label Encoded</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row3_col1" class="data row3 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row4_col0" class="data row4 col0" >Original Data</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row4_col1" class="data row4 col1" >(151, 14)</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row5_col0" class="data row5 col0" >Missing Values</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row5_col1" class="data row5 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row6_col0" class="data row6 col0" >Numeric Features</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row6_col1" class="data row6 col1" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row7_col0" class="data row7 col0" >Categorical Features</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row7_col1" class="data row7 col1" >6</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row8_col0" class="data row8 col0" >Ordinal Features</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row8_col1" class="data row8 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row9_col0" class="data row9 col0" >High Cardinality Features</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row9_col1" class="data row9 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row10_col0" class="data row10 col0" >High Cardinality Method</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row10_col1" class="data row10 col1" >None</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row11" class="row_heading level0 row11" >11</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row11_col0" class="data row11 col0" >Transformed Train Set</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row11_col1" class="data row11 col1" >(99, 16)</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row12" class="row_heading level0 row12" >12</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row12_col0" class="data row12 col0" >Transformed Test Set</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row12_col1" class="data row12 col1" >(46, 16)</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row13" class="row_heading level0 row13" >13</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row13_col1" class="data row13 col1" >True</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row14" class="row_heading level0 row14" >14</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row14_col1" class="data row14 col1" >False</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row15" class="row_heading level0 row15" >15</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row15_col0" class="data row15 col0" >Fold Generator</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row15_col1" class="data row15 col1" >StratifiedKFold</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row16" class="row_heading level0 row16" >16</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row16_col0" class="data row16 col0" >Fold Number</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row16_col1" class="data row16 col1" >10</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row17" class="row_heading level0 row17" >17</th>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row17_col0" class="data row17 col0" >CPU Jobs</td>
#                         <td id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7row17_col1" class="data row17 col1" >-1</td>
#             </tr>
#             <tr>
#                         <th id="T_e1614bf6_6396_11ec_b4d4_d050998ee3c7level0_row1

# %%
best_models = compare_models(sort='f1', n_select=3, fold=5)
# Out:
# <style  type="text/css" >
# #T_ecea508a_6396_11ec_8b82_d050998ee3c7row10_col0,#T_ecea508a_6396_11ec_8b82_d050998ee3c7row10_col1,#T_ecea508a_6396_11ec_8b82_d050998ee3c7row10_col2,#T_ecea508a_6396_11ec_8b82_d050998ee3c7row10_col3,#T_ecea508a_6396_11ec_8b82_d050998ee3c7row10_col4,#T_ecea508a_6396_11ec_8b82_d050998ee3c7row10_col5,#T_ecea508a_6396_11ec_8b82_d050998ee3c7row10_col6{
#             background:  yellow;
#         }</style><table id="T_ecea508a_6396_11ec_8b82_d050998ee3c7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Accuracy</th>        <th class="col_heading level0 col1" >AUC</th>        <th class="col_heading level0 col2" >Recall</th>        <th class="col_heading level0 col3" >Prec.</th>        <th class="col_heading level0 col4" >F1</th>        <th class="col_heading level0 col5" >Kappa</th>        <th class="col_heading level0 col6" >MCC</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_ecea508a_6396_11ec_8b82_d050998ee3c7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row0_col0" class="data row0 col0" >0.8000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row0_col1" class="data row0 col1" >1.0000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row0_col2" class="data row0 col2" >1.0000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row0_col3" class="data row0 col3" >0.7143</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row0_col4" class="data row0 col4" >0.8333</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row0_col5" class="data row0 col5" >0.6000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row0_col6" class="data row0 col6" >0.6547</td>
#             </tr>
#             <tr>
#                         <th id="T_ecea508a_6396_11ec_8b82_d050998ee3c7level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row1_col0" class="data row1 col0" >0.9000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row1_col1" class="data row1 col1" >1.0000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row1_col2" class="data row1 col2" >1.0000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row1_col3" class="data row1 col3" >0.8333</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row1_col4" class="data row1 col4" >0.9091</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row1_col5" class="data row1 col5" >0.8000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row1_col6" class="data row1 col6" >0.8165</td>
#             </tr>
#             <tr>
#                         <th id="T_ecea508a_6396_11ec_8b82_d050998ee3c7level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row2_col0" class="data row2 col0" >0.6000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row2_col1" class="data row2 col1" >0.7600</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row2_col2" class="data row2 col2" >0.4000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row2_col3" class="data row2 col3" >0.6667</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row2_col4" class="data row2 col4" >0.5000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row2_col5" class="data row2 col5" >0.2000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row2_col6" class="data row2 col6" >0.2182</td>
#             </tr>
#             <tr>
#                         <th id="T_ecea508a_6396_11ec_8b82_d050998ee3c7level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row3_col0" class="data row3 col0" >0.9000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row3_col1" class="data row3 col1" >1.0000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row3_col2" class="data row3 col2" >0.8000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row3_col3" class="data row3 col3" >1.0000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row3_col4" class="data row3 col4" >0.8889</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row3_col5" class="data row3 col5" >0.8000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row3_col6" class="data row3 col6" >0.8165</td>
#             </tr>
#             <tr>
#                         <th id="T_ecea508a_6396_11ec_8b82_d050998ee3c7level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row4_col0" class="data row4 col0" >0.9000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row4_col1" class="data row4 col1" >1.0000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row4_col2" class="data row4 col2" >0.8000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row4_col3" class="data row4 col3" >1.0000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row4_col4" class="data row4 col4" >0.8889</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row4_col5" class="data row4 col5" >0.8000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row4_col6" class="data row4 col6" >0.8165</td>
#             </tr>
#             <tr>
#                         <th id="T_ecea508a_6396_11ec_8b82_d050998ee3c7level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row5_col0" class="data row5 col0" >0.9000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row5_col1" class="data row5 col1" >1.0000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row5_col2" class="data row5 col2" >0.8333</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row5_col3" class="data row5 col3" >1.0000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row5_col4" class="data row5 col4" >0.9091</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row5_col5" class="data row5 col5" >0.8000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row5_col6" class="data row5 col6" >0.8165</td>
#             </tr>
#             <tr>
#                         <th id="T_ecea508a_6396_11ec_8b82_d050998ee3c7level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row6_col0" class="data row6 col0" >0.6000</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row6_col1" class="data row6 col1" >0.8750</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row6_col2" class="data row6 col2" >0.8333</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row6_col3" class="data row6 col3" >0.6250</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row6_col4" class="data row6 col4" >0.7143</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row6_col5" class="data row6 col5" >0.0909</td>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row6_col6" class="data row6 col6" >0.1021</td>
#             </tr>
#             <tr>
#                         <th id="T_ecea508a_6396_11ec_8b82_d050998ee3c7level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_ecea508a_6396_11ec_8b82_d050998ee3c7row7_co

# %%
tuned_top3 = [tune_model(i) for i in best_models]
blender = blend_models(tuned_top3)
stacker = stack_models(tuned_top3)
best_auc_model = automl(optimize = 'F1')
finalized_model = finalize_model(best_auc_model)

# %%
predictions = predict_model(data=test, estimator=finalized_model)
predictions[predictions['Label']==1].count()
# Out:
# age         78
# sex         78
# cp          78
# trestbps    78
# chol        78
# fbs         78
# restecg     78
# thalach     78
# exang       78
# oldpeak     78
# slope       78
# ca          74
# thal        78
# Label       78
# Score       78
# dtype: int64

# %% [markdown]
# ## SCORE 0.8275862069

# %%
submission['target'] = predictions['Label']
submission

# %%
submission.to_csv('./submission9.csv')
