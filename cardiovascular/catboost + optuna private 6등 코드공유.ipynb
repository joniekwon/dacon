# %% [markdown]
# https://dacon.io/competitions/official/235848/codeshare/4040?page=1&dtype=recent

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px


from sklearn.model_selection import StratifiedKFold
from sklearn.preprocessing import StandardScaler , LabelEncoder
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from scipy.stats import mode


from xgboost import XGBClassifier
from catboost import CatBoostClassifier
from lightgbm import LGBMClassifier
from sklearn.linear_model import LogisticRegression

import tensorflow as tf
from tensorflow.keras import layers
from tensorflow.keras import callbacks
from tensorflow.keras.utils import to_categorical

from matplotlib import ticker
import time
import warnings

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('float_format', '{:f}'.format)
warnings.filterwarnings('ignore')

# %%
train = pd.read_csv('./_data/train.csv',encoding = 'utf8')
test = pd.read_csv('./_data/test.csv',encoding = 'utf8')

submission = pd.read_csv('./_data/sample_submission.csv')

# %%
train.drop(["id"] , axis = 1 , inplace = True)
test.drop(["id"] , axis = 1 , inplace = True)

train.drop(['trestbps'], axis = 1, inplace=True)
test.drop(['trestbps'], axis = 1, inplace=True)

train.drop(['chol'], axis = 1, inplace=True)
test.drop(['chol'], axis = 1, inplace=True)

train.drop(['fbs'], axis = 1, inplace=True)
test.drop(['fbs'], axis = 1, inplace=True)

train.drop(['restecg'], axis = 1, inplace=True)
test.drop(['restecg'], axis = 1, inplace=True)

# %% [markdown]
# ### catboost 기본 학습 결과

# %%
accuracy =[]
model_names =[]

X= train.drop('target', axis=1)
y= train['target']
categorical_features_indices = np.where(X.dtypes != np.float)[0]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=1111)

model = CatBoostClassifier(verbose=False,random_state=1111)
model.fit(X_train, y_train,cat_features=categorical_features_indices,eval_set=(X_test, y_test))
y_pred = model.predict(X_test)
accuracy.append(round(accuracy_score(y_test, y_pred),4))

model_names = ['Catboost_default']
result_df5 = pd.DataFrame({'Accuracy':accuracy}, index=model_names)
result_df5
# Out:
#                   Accuracy
# Catboost_default  0.811300

# %% [markdown]
# ### optuna를 활용한 파라미터 최적화

# %%
def objective(trial):
    X= train.drop('target', axis=1)
    y= train['target']
    categorical_features_indices = np.where(X.dtypes != np.float)[0]
    
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=1111)

    param = {
        "learning_rate": trial.suggest_float("learning_rate", 0.001, 0.5),
        "objective": trial.suggest_categorical("objective", ["Logloss", "CrossEntropy"]),
        "colsample_bylevel": trial.suggest_float("colsample_bylevel", 0.01, 0.1),
        "depth": trial.suggest_int("depth", 1, 12),
        "boosting_type": trial.suggest_categorical("boosting_type", ["Ordered", "Plain"]),
        "bootstrap_type": trial.suggest_categorical(
            "bootstrap_type", ["Bayesian", "Bernoulli", "MVS"]
        ),
        "used_ram_limit": "3gb",
    }

    if param["bootstrap_type"] == "Bayesian":
        param["bagging_temperature"] = trial.suggest_float("bagging_temperature", 0, 10)
    elif param["bootstrap_type"] == "Bernoulli":
        param["subsample"] = trial.suggest_float("subsample", 0.1, 1)

    cat_cls = CatBoostClassifier(**param)

    cat_cls.fit(X_train, y_train, eval_set=[(X_test, y_test)], cat_features=categorical_features_indices,verbose=0, early_stopping_rounds=100)

    preds = cat_cls.predict(X_test)
    pred_labels = np.rint(preds)
    accuracy = accuracy_score(y_test, pred_labels)
    return accuracy

# %%
import optuna

study = optuna.create_study(direction="maximize")
study.optimize(objective, n_trials=200, timeout=600)

print("Number of finished trials: {}".format(len(study.trials)))

print("Best trial:")
trial = study.best_trial

print("  Value: {}".format(trial.value))

print("  Params: ")
for key, value in trial.params.items():
    print("    {}: {}".format(key, value))
# Out:
# [I 2021-12-26 23:21:55,706] A new study created in memory with name: no-name-8d2f996a-99dc-4bb9-90ed-10789860a31e
# [I 2021-12-26 23:21:57,620] Trial 0 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.2277484690903912, 'objective': 'Logloss', 'colsample_bylevel': 0.059369211604834216, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:21:58,544] Trial 1 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.03524111260349894, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.013533524691805607, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:00,128] Trial 2 finished with value: 0.8490566037735849 and parameters: {'learning_rate': 0.49215306616355187, 'objective': 'Logloss', 'colsample_bylevel': 0.07567758118822693, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.9450128259443413}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:01,578] Trial 3 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.07157026477023329, 'objective': 'Logloss', 'colsample_bylevel': 0.05989995564326258, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:02,344] Trial 4 finished with value: 0.8490566037735849 and parameters: {'learning_rate': 0.4285687209658143, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.04320394618442455, 'depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:04,040] Trial 5 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.14386627406512204, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.03147211752478721, 'depth': 4, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.7495061125691735}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:04,372] Trial 6 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.3980955404569509, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.047762186940834506, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.2936524918203218}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:04,828] Trial 7 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.4564375061204237, 'objective': 'Logloss', 'colsample_bylevel': 0.02644174408714072, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.067379309826407}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:07,974] Trial 8 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.32561856909510134, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.0767672385552432, 'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.34754795013947026}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:09,165] Trial 9 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.43583992116920406, 'objective': 'Logloss', 'colsample_bylevel': 0.04889252496693053, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:16,439] Trial 10 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.24166513141024504, 'objective': 'Logloss', 'colsample_bylevel': 0.09404601179068406, 'depth': 12, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.954454873865883}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:18,673] Trial 11 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.1476493583100188, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.028909095147615853, 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.773852335328409}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:21,473] Trial 12 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.19460478096564332, 'objective': 'Logloss', 'colsample_bylevel': 0.06485103136641775, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:23,646] Trial 13 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.13000383553911038, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.03110010136797585, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.381662738916155}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:25,036] Trial 14 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.29410875457326113, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.010102217093599389, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.10334572869976633}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:26,178] Trial 15 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.212907124204602, 'objective': 'Logloss', 'colsample_bylevel': 0.037587533423520905, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.063539376452014}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:28,309] Trial 16 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.12445323965474013, 'objective': 'Logloss', 'colsample_bylevel': 0.07153052967018043, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:31,025] Trial 17 finished with value: 0.8301886792452831 and parameters: {'learning_rate': 0.001960275326742811, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08800498372037012, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.584020860245644}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:31,662] Trial 18 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.3270164115116186, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.0551519146600663, 'depth': 1, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:33,547] Trial 19 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.10867941956490507, 'objective': 'Logloss', 'colsample_bylevel': 0.020744648458187676, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.965222102452564}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:34,873] Trial 20 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.19111722305085074, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.03631419278745729, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:36,958] Trial 21 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.14823840458196166, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.02022462126580825, 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.7238926719801615}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:38,938] Trial 22 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.08997387037326066, 'objective': 'Logloss', 'colsample_bylevel': 0.022189623762952956, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9770912910203632}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:40,644] Trial 23 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.08923468560408226, 'objective': 'Logloss', 'colsample_bylevel': 0.018350432135411977, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6974638754888547}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:41,713] Trial 24 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.2738051583388331, 'objective': 'Logloss', 'colsample_bylevel': 0.03796667673164427, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6639223742250515}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:43,591] Trial 25 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.17450930343671373, 'objective': 'Logloss', 'colsample_bylevel': 0.054202675855417486, 'depth': 5, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.4668080435327374}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:45,655] Trial 26 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.22484883149607354, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.02985187518830287, 'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.4479395220565}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:48,110] Trial 27 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.052127369300369264, 'objective': 'Logloss', 'colsample_bylevel': 0.06824607434390553, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8296485082183558}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:55,760] Trial 28 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.10659042139436439, 'objective': 'Logloss', 'colsample_bylevel': 0.08413301222566472, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.25030778726651026}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:22:59,808] Trial 29 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.039173572265579486, 'objective': 'Logloss', 'colsample_bylevel': 0.06634496739170445, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7887450858373998}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:23:03,011] Trial 30 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.038793353826256566, 'objective': 'Logloss', 'colsample_bylevel': 0.06184348651856742, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 0 with value: 0.9245283018867925.
# [I 2021-12-26 23:23:10,619] Trial 31 finished with value: 0.9433962264150944 and parameters: {'learning_rate': 0.06119016659487976, 'objective': 'Logloss', 'colsample_bylevel': 0.08421275775556865, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.22985821635839412}. Best is trial 31 with value: 0.9433962264150944.
# [I 2021-12-26 23:23:17,109] Trial 32 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.006520327405861573, 'objective': 'Logloss', 'colsample_bylevel': 0.08456259328976001, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.17109189207789094}. Best is trial 31 with value: 0.9433962264150944.
# [I 2021-12-26 23:23:22,259] Trial 33 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.051604316407620726, 'objective': 'Logloss', 'colsample_bylevel': 0.09929594827022997, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.2771163308108429}. Best is trial 31 with value: 0.9433962264150944.
# [I 2021-12-26 23:23:28,123] Trial 34 finished with value: 0.8490566037735849 and parameters: {'learning_rate': 0.06752955671835495, 'objective': 'Logloss', 'colsample_bylevel': 0.08016752370740102, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.4527863306604169}. Best is trial 31 with value: 0.9433962264150944.
# [I 2021-12-26 23:23:30,527] Trial 35 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.08024129655685919, 'objective': 'Logloss', 'colsample_bylevel': 0.06891492263401165, 'depth': 12, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.2622468096540536}. Best is trial 31 with value: 0.9433962264150944.
# [I 2021-12-26 23:23:33,795] Trial 36 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.019054797288014, 'objective': 'Logloss', 'colsample_bylevel': 0.057580871996133313, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8171708249020488}. Best is trial 31 with value: 0.9433962264150944.
# [I 2021-12-26 23:23:35,144] Trial 37 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.15938144886662503, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.0885335957458013, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 31 with value: 0.9433962264150944.
# [I 2021-12-26 23:23:37,109] Trial 38 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.11953707280321418, 'objective': 'Logloss', 'colsample_bylevel': 0.013784069445071878, 'depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.12452528020798659}. Best is trial 31 with value: 0.9433962264150944.
# [I 2021-12-26 23:23:40,168] Trial 39 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.35236846988582327, 'objective': 'Logloss', 'colsample_bylevel': 0.07375235536064635, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5431082351161404}. Best is trial 31 with value: 0.9433962264150944.
# [I 2021-12-26 23:23:47,500] Trial 40 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.05983796714564227, 'objective': 'Logloss', 'colsample_bylevel': 0.08160404230770743, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.2782161771745305}. Best is trial 31 with value: 0.9433962264150944.
# [I 2021-12-26 23:23:49,550] Trial 41 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.10181085499355605, 'objective': 'Logloss', 'colsample_bylevel': 0.04744705889967962, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 31 with value: 0.9433962264150944.
# [I 2021-12-26 23:23:52,379] Trial 42 finished with value: 0.9622641509433962 and parameters: {'learning_rate': 0.17535595403535204, 'objective': 'Logloss', 'colsample_bylevel': 0.0774526052408897, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.4097550363316602}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:23:56,767] Trial 43 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.10956964339395137, 'objective': 'Logloss', 'colsample_bylevel': 0.07958077188295201, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8997632475617132}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:23:57,901] Trial 44 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.25571292925332656, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.04370776917111226, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.120886677671232}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:01,558] Trial 45 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.16925873444252143, 'objective': 'Logloss', 'colsample_bylevel': 0.09203411827137242, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.391823701191456}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:02,347] Trial 46 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.25534253027303705, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.0426431121667819, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.075384889494537}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:05,900] Trial 47 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.12779681347749594, 'objective': 'Logloss', 'colsample_bylevel': 0.07668451764571411, 'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.1919731442351454}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:10,026] Trial 48 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.1962502889697539, 'objective': 'Logloss', 'colsample_bylevel': 0.08571440918523922, 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3584556796726188}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:11,072] Trial 49 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.13682062317282326, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.030741804855259083, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 9.258582813507314}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:12,282] Trial 50 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.21710384283381873, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.05199505861157469, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 7.387483598723957}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:12,942] Trial 51 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.24138386129087597, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.025661555874268067, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.739578967453716}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:13,538] Trial 52 finished with value: 0.9433962264150944 and parameters: {'learning_rate': 0.18495954340469742, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.03464600243101275, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.306338718222149}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:14,379] Trial 53 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.2838242450264942, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.04299129260722405, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.172470040537888}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:15,304] Trial 54 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.17424398539719127, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.07219301846600763, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5754296573250179}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:18,130] Trial 55 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.26324037291945473, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09548121389740155, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:18,673] Trial 56 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.30836757508765916, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.03410871818569128, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.172945463811246}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:19,422] Trial 57 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.18813947022945685, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.06217579397469736, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:20,564] Trial 58 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.2356443073949729, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.07256825826488973, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.336845288001328}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:27,422] Trial 59 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.02684568465244546, 'objective': 'Logloss', 'colsample_bylevel': 0.09081432970414127, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.2033199060638926}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:27,985] Trial 60 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.3697108903767054, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.039937881515014206, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:29,061] Trial 61 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.15777427836639976, 'objective': 'Logloss', 'colsample_bylevel': 0.06842188084833853, 'depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6361075178212431}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:35,156] Trial 62 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.21138105517870837, 'objective': 'Logloss', 'colsample_bylevel': 0.09050082183284765, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.1370679061758629}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:39,707] Trial 63 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.18246433726943304, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08513520882459408, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.20979675193617292}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:40,713] Trial 64 finished with value: 0.8490566037735849 and parameters: {'learning_rate': 0.492873798534325, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09611388650416508, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5577507567351098}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:42,709] Trial 65 finished with value: 0.9433962264150944 and parameters: {'learning_rate': 0.09738382850032562, 'objective': 'Logloss', 'colsample_bylevel': 0.021546126348328743, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.9827916515191903}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:43,312] Trial 66 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.2060238215203389, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.025059486619949466, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.0041568256202726}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:47,888] Trial 67 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.1056990917022605, 'objective': 'Logloss', 'colsample_bylevel': 0.08132459745775908, 'depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:49,813] Trial 68 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.0679427202233285, 'objective': 'Logloss', 'colsample_bylevel': 0.017212675795162235, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.4178065525554833}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:50,587] Trial 69 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.1455693738572711, 'objective': 'Logloss', 'colsample_bylevel': 0.07690411332155944, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5256357833974614}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:53,955] Trial 70 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.013134686243300886, 'objective': 'Logloss', 'colsample_bylevel': 0.06426071985729483, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:55,407] Trial 71 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.1530323211429375, 'objective': 'Logloss', 'colsample_bylevel': 0.04693818931749934, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.3086141214337954}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:57,311] Trial 72 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.09329071652020514, 'objective': 'Logloss', 'colsample_bylevel': 0.015110686944151167, 'depth': 6, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.773506236729601}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:58,593] Trial 73 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.07945863862432179, 'objective': 'Logloss', 'colsample_bylevel': 0.022379476105854397, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.198081119931368}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:24:59,557] Trial 74 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.04449020851942957, 'objective': 'Logloss', 'colsample_bylevel': 0.016816448765162452, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.4220850070125133}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:01,521] Trial 75 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.07615032922959764, 'objective': 'Logloss', 'colsample_bylevel': 0.020936740876613732, 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.258295746532073}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:07,781] Trial 76 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.02504488471657039, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08778045927865448, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.33953759289577407}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:09,060] Trial 77 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.06421511274888225, 'objective': 'Logloss', 'colsample_bylevel': 0.02783208943479776, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.666267446700394}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:11,416] Trial 78 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.04459716978066557, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.03501177543112387, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3315929151165879}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:12,406] Trial 79 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.0850747993938657, 'objective': 'Logloss', 'colsample_bylevel': 0.08729129791105135, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.4835755695050064}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:15,665] Trial 80 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.026650017464527442, 'objective': 'Logloss', 'colsample_bylevel': 0.07831401442880143, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 8.456794985123995}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:17,398] Trial 81 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.11430459511716198, 'objective': 'Logloss', 'colsample_bylevel': 0.012566453678653574, 'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.132238790315404}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:19,247] Trial 82 finished with value: 0.8490566037735849 and parameters: {'learning_rate': 0.17427522966418635, 'objective': 'Logloss', 'colsample_bylevel': 0.07063880225692859, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.13320522482519012}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:21,118] Trial 83 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.12462077318508985, 'objective': 'Logloss', 'colsample_bylevel': 0.023595702294028766, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6001503560749017}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:23,753] Trial 84 finished with value: 0.8301886792452831 and parameters: {'learning_rate': 0.22925198172983335, 'objective': 'Logloss', 'colsample_bylevel': 0.08253708872884243, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.2685971863892912}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:25,106] Trial 85 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.0533462288744124, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.03379797565807052, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.1660190866071534}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:27,204] Trial 86 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.08669458716476569, 'objective': 'Logloss', 'colsample_bylevel': 0.08765887114516122, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.577479084999258}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:28,418] Trial 87 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.4669884340175806, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.07436535110471196, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.2385475879329626}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:29,146] Trial 88 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.14123054639287533, 'objective': 'Logloss', 'colsample_bylevel': 0.011536582129049445, 'depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.4871538445130757}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:31,500] Trial 89 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.0386179465078466, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.04987698618599508, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.5748760179218513}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:37,540] Trial 90 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.027079493713689586, 'objective': 'Logloss', 'colsample_bylevel': 0.0870619661392207, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.9283760145728222}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:39,507] Trial 91 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.24914343501277764, 'objective': 'Logloss', 'colsample_bylevel': 0.05782917453715371, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3940817423843401}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:45,318] Trial 92 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.0063327348240957565, 'objective': 'Logloss', 'colsample_bylevel': 0.09081896997861981, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7310555264746352}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:46,275] Trial 93 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.19765976979293168, 'objective': 'Logloss', 'colsample_bylevel': 0.018606341923458086, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.31470793083208026}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:50,843] Trial 94 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.16564393868167696, 'objective': 'Logloss', 'colsample_bylevel': 0.06559360201594944, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:25:57,468] Trial 95 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.05748659949858698, 'objective': 'Logloss', 'colsample_bylevel': 0.09316246556207186, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.21415648614208527}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:03,034] Trial 96 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.09630570754847499, 'objective': 'Logloss', 'colsample_bylevel': 0.08332704327547319, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3385729898336447}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:03,871] Trial 97 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.2639752130654265, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.04062932926478724, 'depth': 8, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3118632450282721}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:04,661] Trial 98 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.3022326215688394, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.06823871610724058, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.3329376248984584}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:07,057] Trial 99 finished with value: 0.8490566037735849 and parameters: {'learning_rate': 0.20122631886347067, 'objective': 'Logloss', 'colsample_bylevel': 0.07889974205699951, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:08,722] Trial 100 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.07273645712643947, 'objective': 'Logloss', 'colsample_bylevel': 0.04602861231301282, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.49443280337673107}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:09,687] Trial 101 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.13484373356364474, 'objective': 'Logloss', 'colsample_bylevel': 0.07528123060881108, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5330104479721608}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:12,071] Trial 102 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.07460003874936288, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.044943226431063674, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.629488744318551}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:18,457] Trial 103 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.030799894931413788, 'objective': 'Logloss', 'colsample_bylevel': 0.0896139473138276, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7275778891814226}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:20,469] Trial 104 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.14836065126963693, 'objective': 'Logloss', 'colsample_bylevel': 0.02223291806424273, 'depth': 12, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9417170545267701}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:22,434] Trial 105 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.06598874233070084, 'objective': 'Logloss', 'colsample_bylevel': 0.0181725748655609, 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.16105993635862342}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:23,392] Trial 106 finished with value: 0.9433962264150944 and parameters: {'learning_rate': 0.11792754766528457, 'objective': 'Logloss', 'colsample_bylevel': 0.028026318262609772, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.10298018937629003}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:24,702] Trial 107 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.11145990473667432, 'objective': 'Logloss', 'colsample_bylevel': 0.027259695254368423, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.11704814188977225}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:25,782] Trial 108 finished with value: 0.8490566037735849 and parameters: {'learning_rate': 0.18487279582449623, 'objective': 'Logloss', 'colsample_bylevel': 0.07743197323985802, 'depth': 5, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.10104028762105853}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:26,986] Trial 109 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.12172707110054701, 'objective': 'Logloss', 'colsample_bylevel': 0.02636816372952438, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.14377083219308817}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:27,603] Trial 110 finished with value: 0.8490566037735849 and parameters: {'learning_rate': 0.2825238083950548, 'objective': 'Logloss', 'colsample_bylevel': 0.023614572095272447, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.793872721234976}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:32,359] Trial 111 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.004338591016956607, 'objective': 'Logloss', 'colsample_bylevel': 0.08517415781306152, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:32,923] Trial 112 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.1630853306608648, 'objective': 'Logloss', 'colsample_bylevel': 0.030141250476117088, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.705385719277847}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:35,247] Trial 113 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.05024573374631142, 'objective': 'Logloss', 'colsample_bylevel': 0.03470385017975163, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.4293975924857688}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:38,577] Trial 114 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.0930001848108514, 'objective': 'Logloss', 'colsample_bylevel': 0.07163740711383812, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8219976289022167}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:39,322] Trial 115 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.219605823432156, 'objective': 'Logloss', 'colsample_bylevel': 0.08040742822145239, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.698231898665797}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:40,974] Trial 116 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.10337422516147085, 'objective': 'Logloss', 'colsample_bylevel': 0.06271476064631004, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.2389149867481121}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:41,642] Trial 117 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.1770292865758541, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.01934847193658054, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:43,498] Trial 118 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.04535688325779899, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.01581501157580114, 'depth': 9, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3616340684912984}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:44,662] Trial 119 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.1429063169073566, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.0378569202669428, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.884589510368923}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:46,215] Trial 120 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.13161261653007533, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.032190759971678654, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.049769300805076}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:50,327] Trial 121 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.08391219463261251, 'objective': 'Logloss', 'colsample_bylevel': 0.08633364021062152, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.30540401678512646}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:51,514] Trial 122 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.11285716450990382, 'objective': 'Logloss', 'colsample_bylevel': 0.02883876403748318, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.18465493206344896}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:26:57,218] Trial 123 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.004129548642797893, 'objective': 'Logloss', 'colsample_bylevel': 0.0838638545149198, 'depth': 7, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:27:03,836] Trial 124 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.008342917973177405, 'objective': 'Logloss', 'colsample_bylevel': 0.09862479245055031, 'depth': 6, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:27:06,535] Trial 125 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.07925625668185451, 'objective': 'Logloss', 'colsample_bylevel': 0.09252275392053938, 'depth': 1, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.738221773065324}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:27:14,459] Trial 126 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.0199213212163116, 'objective': 'Logloss', 'colsample_bylevel': 0.08710043562723721, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.2666373101276811}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:27:21,162] Trial 127 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.055455429057593784, 'objective': 'Logloss', 'colsample_bylevel': 0.08991881486055969, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.8108361239267647}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:27:22,907] Trial 128 finished with value: 0.9433962264150944 and parameters: {'learning_rate': 0.23052053419431748, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.050964864851861566, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6034101247833962}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:27:23,744] Trial 129 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.23248879420944385, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.049526815746258536, 'depth': 12, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5725487898392879}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:27:26,495] Trial 130 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.10164129531315992, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.056552393275598786, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6675578070568126}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:27:30,085] Trial 131 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.06540833060509202, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.05169564117161948, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.623532207380979}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:27:31,686] Trial 132 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.1504399510261961, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.03246989133810961, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.5875008167361639}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:27:39,336] Trial 133 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.02280844840389852, 'objective': 'Logloss', 'colsample_bylevel': 0.09509801049942854, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.6230817845057168}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:27:45,175] Trial 134 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.03918107312623688, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08181916067018717, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.9016394583471083}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:27:46,751] Trial 135 finished with value: 0.8490566037735849 and parameters: {'learning_rate': 0.07176550242162139, 'objective': 'Logloss', 'colsample_bylevel': 0.04528498850457154, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.5721495661998262}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:27:49,464] Trial 136 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.08416655425708543, 'objective': 'Logloss', 'colsample_bylevel': 0.053238320421241034, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 0.9838752977679619}. Best is trial 42 with value: 0.9622641509433962.
# ...
# [I 2021-12-26 23:28:32,605] Trial 156 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.016600428369831395, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.055489373080695695, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3311503134336562}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:28:38,339] Trial 157 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.18788754502267296, 'objective': 'Logloss', 'colsample_bylevel': 0.08676614352871659, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.2625159165299158}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:28:39,841] Trial 158 finished with value: 0.8490566037735849 and parameters: {'learning_rate': 0.09293911448133803, 'objective': 'Logloss', 'colsample_bylevel': 0.08133589341821706, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.649703192805718}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:28:42,652] Trial 159 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.16985395545915338, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08332706857881067, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.38656354275137345}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:28:46,837] Trial 160 finished with value: 0.8490566037735849 and parameters: {'learning_rate': 0.1407169721537655, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.07726031491992631, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.1705941246738179}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:28:54,440] Trial 161 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.07373770182997455, 'objective': 'Logloss', 'colsample_bylevel': 0.08923917857049272, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.17497228024547}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:28:55,520] Trial 162 finished with value: 0.9433962264150944 and parameters: {'learning_rate': 0.036013810530542784, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.022207239891797743, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.58232050118844}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:28:56,575] Trial 163 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.07846513266430982, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.017195619066124605, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.186937649465668}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:28:57,707] Trial 164 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.03733338610798897, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.022765910025161987, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.486306482470571}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:02,626] Trial 165 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.0011709175639825712, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.08546718510420673, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.761263872571645}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:03,682] Trial 166 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.05949535005861208, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.020521770403654632, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.3658342511557846}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:05,768] Trial 167 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.09129385485160406, 'objective': 'Logloss', 'colsample_bylevel': 0.02422948273715776, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.8332283711476514}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:06,799] Trial 168 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.056842069457406365, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.020514857174687744, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.796402452649872}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:08,744] Trial 169 finished with value: 0.9433962264150944 and parameters: {'learning_rate': 0.10501326119894797, 'objective': 'Logloss', 'colsample_bylevel': 0.025752190004961296, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.7724634605549148}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:17,236] Trial 170 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.11703161027545195, 'objective': 'Logloss', 'colsample_bylevel': 0.09189535178751754, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.224477759189597}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:27,621] Trial 171 finished with value: 0.8490566037735849 and parameters: {'learning_rate': 0.029569603614610692, 'objective': 'Logloss', 'colsample_bylevel': 0.09374864738662936, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.9357098408535105}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:30,422] Trial 172 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.10442357112293044, 'objective': 'Logloss', 'colsample_bylevel': 0.03662460084277409, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.0445302425836385}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:32,873] Trial 173 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.024491777299096726, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.025766218813060376, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.645456897160766}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:33,750] Trial 174 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.10772253760564551, 'objective': 'Logloss', 'colsample_bylevel': 0.03972462716530214, 'depth': 12, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:37,692] Trial 175 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.06742717738746823, 'objective': 'Logloss', 'colsample_bylevel': 0.08965713550261274, 'depth': 10, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.7883520569829505}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:39,156] Trial 176 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.12643655888253955, 'objective': 'Logloss', 'colsample_bylevel': 0.06979974806482207, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:42,055] Trial 177 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.11313182451357906, 'objective': 'Logloss', 'colsample_bylevel': 0.0682306733949968, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:43,965] Trial 178 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.04565704578112102, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.022496859564650917, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 5.272910152000432}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:44,536] Trial 179 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.2660567428703695, 'objective': 'Logloss', 'colsample_bylevel': 0.013564694759104576, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.11872159736856039}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:45,576] Trial 180 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.07436344834126807, 'objective': 'Logloss', 'colsample_bylevel': 0.018044828790724974, 'depth': 9, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 6.463378999425211}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:46,846] Trial 181 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.22249044589386727, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.03082467288944304, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.15517668730266368}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:48,211] Trial 182 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.1344713611731256, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.0297255649790417, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.43216037549645786}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:50,518] Trial 183 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.01308157174883911, 'objective': 'Logloss', 'colsample_bylevel': 0.05784586286786136, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:51,524] Trial 184 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.09928085785629705, 'objective': 'Logloss', 'colsample_bylevel': 0.027201412348953347, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.48852419808305025}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:51,961] Trial 185 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.23984737189052838, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.024989240551878716, 'depth': 8, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.12719146971437456}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:52,334] Trial 186 finished with value: 0.8679245283018868 and parameters: {'learning_rate': 0.42463510391466797, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.026704986590276154, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.547790424659526}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:29:54,177] Trial 187 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.08164234573623416, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.02131090815107246, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.8493535149205957}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:30:02,060] Trial 188 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.03863448844410576, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.09135143338359089, 'depth': 11, 'boosting_type': 'Plain', 'bootstrap_type': 'Bernoulli', 'subsample': 0.6945931282187695}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:30:03,827] Trial 189 finished with value: 0.9433962264150944 and parameters: {'learning_rate': 0.009357444055764245, 'objective': 'Logloss', 'colsample_bylevel': 0.053240596224836303, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:30:05,533] Trial 190 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.08279923504692585, 'objective': 'Logloss', 'colsample_bylevel': 0.0743019410545226, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.063133628548011}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:30:07,729] Trial 191 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.006282308563559909, 'objective': 'Logloss', 'colsample_bylevel': 0.05486733598723634, 'depth': 10, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:30:10,527] Trial 192 finished with value: 0.8490566037735849 and parameters: {'learning_rate': 0.00258701956201764, 'objective': 'Logloss', 'colsample_bylevel': 0.059341250155437925, 'depth': 12, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:30:12,231] Trial 193 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.0160190912446255, 'objective': 'Logloss', 'colsample_bylevel': 0.049732502395513564, 'depth': 3, 'boosting_type': 'Plain', 'bootstrap_type': 'MVS'}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:30:14,453] Trial 194 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.09324579984685337, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.03619312773121365, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 4.192198621046222}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:30:16,472] Trial 195 finished with value: 0.9056603773584906 and parameters: {'learning_rate': 0.08745222039554729, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.023938603626758523, 'depth': 11, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 3.4482965420188085}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:30:18,602] Trial 196 finished with value: 0.8867924528301887 and parameters: {'learning_rate': 0.05611669515394555, 'objective': 'Logloss', 'colsample_bylevel': 0.0842967833977639, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.8646806868141814}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:30:19,746] Trial 197 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.12061361951730347, 'objective': 'Logloss', 'colsample_bylevel': 0.0786360523986249, 'depth': 4, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 2.2803828783938167}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:30:21,582] Trial 198 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.052589685655176174, 'objective': 'CrossEntropy', 'colsample_bylevel': 0.0162331752294188, 'depth': 3, 'boosting_type': 'Ordered', 'bootstrap_type': 'Bernoulli', 'subsample': 0.36147624431954367}. Best is trial 42 with value: 0.9622641509433962.
# [I 2021-12-26 23:30:23,202] Trial 199 finished with value: 0.9245283018867925 and parameters: {'learning_rate': 0.02476988009602059, 'objective': 'Logloss', 'colsample_bylevel': 0.05331520798044838, 'depth': 2, 'boosting_type': 'Plain', 'bootstrap_type': 'Bayesian', 'bagging_temperature': 1.766243115138493}. Best is trial 42 with value: 0.9622641509433962.
# Number of finished trials: 200
# Best trial:
#   Value: 0.9622641509433962
#   Params:
#     learning_rate: 0.17535595403535204
#     objective: Logloss
#     colsample_bylevel: 0.0774526052408897
#     depth: 10
#     boosting_type: Plain
#     bootstrap_type: Bernoulli
#     subsample: 0.4097550363316602

# %% [markdown]
# ### optuna를 통해 나온 파라미터를 사용하여 학습

# %%
from sklearn.metrics import accuracy_score, classification_report

accuracy =[]
model_names =[]


X= train.drop('target', axis=1)
y= train['target']
categorical_features_indices = np.where(X.dtypes != np.float)[0]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.35, random_state=1111)
        
model = CatBoostClassifier(
    verbose=False,
    learning_rate=0.11318298060181874,
    objective= 'Logloss',
    colsample_bylevel= 0.04636567857984003,
    depth= 3,
    boosting_type= 'Ordered',
    bootstrap_type= 'Bayesian',
    bagging_temperature=0.39557095371902345
)

model.fit(X_train, y_train,cat_features=categorical_features_indices,eval_set=(X_test, y_test))

y_pred = model.predict(X_test)
accuracy.append(round(accuracy_score(y_test, y_pred),4))
print(classification_report(y_test, y_pred))

model_names = ['Catboost_tuned']
result_df6 = pd.DataFrame({'Accuracy':accuracy}, index=model_names)
result_df6
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.92      0.96        24
#            1       0.94      1.00      0.97        29
#
#     accuracy                           0.96        53
#    macro avg       0.97      0.96      0.96        53
# weighted avg       0.96      0.96      0.96        53
#                 Accuracy
# Catboost_tuned  0.962300

# %% [markdown]
# ### 최종 결과 확인

# %%
y_pred = model.predict(test)

# %%
submission = submission.copy()
submission['target'] = y_pred
submission.to_csv("catboost_optuna.csv",index=None)
submission.head()
# Out:
#    id  target
# 0   1       0
# 1   2       1
# 2   3       0
# 3   4       0
# 4   5       1
